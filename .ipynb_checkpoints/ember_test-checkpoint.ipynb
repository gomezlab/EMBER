# %%
import numpy as np
from IPython.display import Audio, display
import torch
import random
from torch import optim
import math

import copy
import torch.utils.data as data_utils
import numpy
import matplotlib.pyplot as plt

mySeed = 666
random.seed(mySeed)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

device
# Out:
# device(type='cuda', index=0)

# %%
motifs_train = (np.genfromtxt('model_data/motifs_train.csv',dtype='U'))
motifxFamMatrix_train = np.genfromtxt('model_data/motifxFamMatrix_train.csv',delimiter=',',dtype=int)

motifs_test = (np.genfromtxt('model_data/motifs_test.csv',dtype='U'))
motifxFamMatrix_test = np.genfromtxt('model_data/motifxFamMatrix_test.csv',delimiter=',',dtype=int)

fams = (np.genfromtxt('model_data/fams.csv',dtype='U'))

motifs_all = np.hstack((motifs_train,motifs_test))
motifxFamMatrix_all = np.vstack((motifxFamMatrix_train,motifxFamMatrix_test))

# %%
## split train into train and val sets ...

idc_val = random.sample(range(len(motifs_train)), len(motifs_train)//8)
idc_train = [i for i in range(len(motifs_train)) if i not in idc_val]

motifs_val = motifs_train[idc_val]
motifxFamMatrix_val = motifxFamMatrix_train[idc_val]

motifs_train = motifs_train[idc_train]
motifxFamMatrix_train = motifxFamMatrix_train[idc_train]

target_train = torch.tensor(motifxFamMatrix_train).float()
target_val = torch.tensor(motifxFamMatrix_val).float()
target_test = torch.tensor(motifxFamMatrix_test).float()

# %%
print(target_train.shape)
print(target_val.shape)
print(target_test.shape)

print(motifs_train.shape)
print(motifs_val.shape)
print(motifs_test.shape)
# Out:
# torch.Size([5844, 8])
# torch.Size([834, 8])
# torch.Size([857, 8])
# (5844,)
# (834,)
# (857,)

# %%
all_characters = []
for motif in motifs_all:
    for c in motif:
        all_characters.append(c)
amino_acids = ''.join(list(set(all_characters)))

# %%
len(amino_acids)*15
# Out:
# 330

# %%
amino_acids
# Out:
# 'KSPACDRVWHX_GFQYLTMNEI'

# %%
pamFams = (np.genfromtxt('data/fams_forPamDistMatrix_19.10.16.csv',dtype='U'))
pamMatrix = (np.genfromtxt('data/famDistanceMatrix_pam_19.10.16.csv',delimiter=',',dtype=float))

for i,each in enumerate(pamFams):
    pamFams[i] = each.upper()

famDistMatrix = np.full((len(fams),len(fams)),-1.0)

for fam in fams:
    fIdx1_set = np.where(fams==fam)[0][0]
    fIdx1_get = np.where(pamFams==fam)[0][0]
    for fam2 in fams:
        fIdx2_set = np.where(fams==fam2)[0][0]
        fIdx2_get = np.where(pamFams==fam2)[0][0]
        famDistMatrix[fIdx1_set][fIdx2_set] = pamMatrix[fIdx1_get][fIdx2_get]

# %% [markdown]
# ### <font color=blue> Normalize fam distances.

# %%
maximum = np.max(famDistMatrix)
minimum = np.min(famDistMatrix)

famDistMatrix_scaled = np.array((famDistMatrix))
for i in range(len(fams)):
    for j in range(len(fams)):
        famDistMatrix_scaled[i][j] = float(famDistMatrix[i][j]-minimum)/(maximum-minimum)

# %%
famDistMatrix = famDistMatrix_scaled

# %%
def allDone():
    urL = 'http://www.wavsource.com/snds_2018-06-03_5106726768923853/animals/cat_meow2.wav'
    display(Audio(url=urL, autoplay=True))
    
allDone()
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="http://www.wavsource.com/snds_2018-06-03_5106726768923853/animals/cat_meow2.wav" type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fam_counts = []
for fIdx,fam in enumerate(motifxFamMatrix_train.T):
#     print (fams[fIdx],np.sum(motifxFamMatrix_train.T[fIdx]))
    fam_counts.append(np.sum(motifxFamMatrix_train.T[fIdx]))
fam_counts = np.array(fam_counts)

normalized_fam_counts = fam_counts / np.sqrt(np.sum(fam_counts**2))

for i in range(len(normalized_fam_counts)):
    normalized_fam_counts[i] = 1-normalized_fam_counts[i]
normalized_fam_counts = np.array(normalized_fam_counts) 
normalized_fam_counts = torch.from_numpy( np.array(normalized_fam_counts)) 
normalized_fam_counts = normalized_fam_counts.double()
normalized_fam_counts = normalized_fam_counts.to(device)

# %%
for fIdx,fam in enumerate(motifxFamMatrix_all.T):
    print (fams[fIdx],np.sum(motifxFamMatrix_all.T[fIdx]))
# Out:
# PKA 1533
# AKT 464
# CDK 903
# MAPK 1514
# SRC 993
# CK2 900
# PKC 1801
# PIKK 574

# %%
len(_motifs)
# Out:
# 7535

# %%
_motifs = []
for fIdx,fam in enumerate(motifxFamMatrix_all.T):
    for mIdx,motif in enumerate(fam):
        if motif==1 and motifs_all[mIdx] not in _motifs:
            _motifs.append(motifs_all[mIdx])
#     print (fams[fIdx],np.sum(motifxFamMatrix_all.T[fIdx]))

# %%
def letterToIndex(letter):
    return amino_acids.find(letter)

def motifToStringTensor(motif):
    motif = [letterToIndex(x) for x in motif]
    motif = torch.tensor(motif).unsqueeze(1)
    return (motif)

# %%
siamRun = '08'

pos_train = np.genfromtxt('siamese_results/%s_embedding_motifs_train.csv' % siamRun,
                          delimiter=',',dtype=float)
dim3 = pos_train.shape[1] // 15

pos_train = pos_train.reshape(pos_train.shape[0],15,dim3)
pos_val = pos_train[idc_val]
pos_train = pos_train[idc_train]

pos_test = np.genfromtxt('siamese_results/%s_embedding_motifs_test.csv' % siamRun,
                         delimiter=',',dtype=float)
pos_test = pos_test.reshape(pos_test.shape[0],15,dim3)

# %%
print(pos_train.shape)
print(pos_val.shape)
print(pos_test.shape)
# Out:
# (5844, 15, 100)
# (834, 15, 100)
# (857, 15, 100)

# %%
def letterToIndex(letter):
    return amino_acids.find(letter)

def letterToTensor(letter):
    tensor = torch.zeros(1, len(amino_acids))
    tensor[0][letterToIndex(letter)] = 1
    return tensor

def lineToTensor(line):
    tensor = torch.zeros(len(line), 1, len(amino_acids))
    for li, letter in enumerate(line):
        tensor[li][0][letterToIndex(letter)] = 1
    return tensor.squeeze()

# %%
features_train = [] 
features_val = [] 
features_test = [] 

for mIdx, motif in enumerate(motifs_train):
    motif_tensor = lineToTensor(motif).float() ########################
    coords = torch.tensor(pos_train[mIdx])
    feature = torch.cat((motif_tensor.float(), coords.float()), 1)
    features_train.append(torch.tensor(feature.detach().numpy())) ########################
features_train = torch.stack(features_train)

for mIdx, motif in enumerate(motifs_val):
    motif_tensor = lineToTensor(motif).float() ########################
    coords = torch.tensor(pos_val[mIdx])
    feature = torch.cat((motif_tensor.float(), coords.float()), 1)
    features_val.append(torch.tensor(feature.detach().numpy())) ########################
features_val = torch.stack(features_val)

for mIdx, motif in enumerate(motifs_test):
    motif_tensor = lineToTensor(motif).float() ########################
    coords = torch.tensor(pos_test[mIdx])
    feature = torch.cat((motif_tensor.float(), coords.float()), 1)
    features_test.append(torch.tensor(feature.detach().numpy())) ########################
features_test = torch.stack(features_test)

# %%
print (features_train.shape)
print (features_val.shape)
print (features_test.shape)
# Out:
# torch.Size([5844, 15, 122])
# torch.Size([834, 15, 122])
# torch.Size([857, 15, 122])

# %%
from sklearn.metrics import roc_curve, auc
from scipy import interp
import numpy as np

def getMicroROC(y_test, y_score):
        
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    
    for i in range(len(fams)):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

        
    return roc_auc["micro"]

# %%
from itertools import chain
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score

def getPRC(y_test, y_score):
        
    precision = dict()
    recall = dict()
    average_precision = dict()
        
    for i in range(len(fams)):
        precision[i], recall[i], _ = precision_recall_curve(y_test[:, i], y_score[:, i])
        average_precision[i] = average_precision_score(y_test[:, i], y_score[:, i])
        
    precision["micro"], recall["micro"], _ = precision_recall_curve(y_test.ravel(), y_score.ravel())
    average_precision["micro"] = average_precision_score(y_test, y_score, average="micro")
        
    return average_precision["micro"]

# %%
def eval_model(model, thresh=0.5):
        
    BATCH_SIZE = len(motifs_test)

    test = data_utils.TensorDataset(features_test, target_test)
    test_loader = data_utils.DataLoader(test, batch_size=BATCH_SIZE, shuffle=True, drop_last=False)
    
    for inputs, labels in test_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)
        
        sentence = inputs[:,:,:len(amino_acids)]
        coords = inputs[:,:,len(amino_acids):]
        outputs = model(sentence=sentence,coords=coords)   # Set model to evaluate mode

        accuracy = 0.0
        for i,out in enumerate(outputs):
            pred = numpy.where(out.cpu().detach().numpy() > thresh)[0]
            if len(pred)<1:
                pred = [numpy.argmax(out.cpu().detach().numpy())]
            true = numpy.where(labels.data.cpu()[i]==1)[0]
            if any(true) in pred:
                accuracy+=1

        y_score = outputs.cpu().detach().numpy()
        y_test = numpy.array(labels.cpu())
        
        print(accuracy)
        
        return (accuracy/BATCH_SIZE, y_score, y_test)

# %%
catDrpt = 0.0

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

HIDDEN_DIM_0 = 64
HIDDEN_DIM_1 = 32
OUT_DIM = len(fams)

class Model(nn.Module):
    def __init__(self, batch_size, motifDrpt, coordDrpt, catDrpt):
        super(Model, self).__init__()
        
        self.motif_conv1 = nn.Conv1d(in_channels=len(amino_acids), out_channels=HIDDEN_DIM_0, kernel_size=1, stride=1)
        self.motif_conv2 = nn.Conv1d(in_channels=HIDDEN_DIM_0, out_channels=HIDDEN_DIM_1, kernel_size=2, stride=1)
        self.motif_conv3 = nn.Conv1d(in_channels=HIDDEN_DIM_1, out_channels=HIDDEN_DIM_1, kernel_size=3, stride=1)
        self.motif_fc1 = nn.Linear(384, HIDDEN_DIM_0) # 192 #768
        self.motif_fc2 = nn.Linear(HIDDEN_DIM_0, HIDDEN_DIM_0)
        
                
        # coords CNN 
        self.conv1 = nn.Conv1d(in_channels=pos_train.shape[2], out_channels=HIDDEN_DIM_0, kernel_size=1, stride=1)
        self.conv2 = nn.Conv1d(in_channels=HIDDEN_DIM_0, out_channels=HIDDEN_DIM_1, kernel_size=2, stride=1)
        self.conv3 = nn.Conv1d(in_channels=HIDDEN_DIM_1, out_channels=HIDDEN_DIM_1, kernel_size=3, stride=1)
        self.fc1 = nn.Linear(384, HIDDEN_DIM_0) # 192 #768            
        self.fc2 = nn.Linear(HIDDEN_DIM_0, HIDDEN_DIM_0)

        # concat
        self.cat_fc1 = nn.Linear(HIDDEN_DIM_0 + HIDDEN_DIM_0, HIDDEN_DIM_0)
        self.cat_fc2 = nn.Linear(HIDDEN_DIM_0, HIDDEN_DIM_0)
        self.cat_bn2 = nn.BatchNorm1d(HIDDEN_DIM_0)
        self.cat_out = nn.Linear(HIDDEN_DIM_0, OUT_DIM)
        
        self.output = nn.Linear(HIDDEN_DIM_0, OUT_DIM)
        self.sigmoid = nn.Sigmoid()
        
        self.relu = nn.ReLU()
        self.bn0 = nn.BatchNorm1d(HIDDEN_DIM_0)
        self.bn1 = nn.BatchNorm1d(HIDDEN_DIM_1)
        
        myMotifDrpt = motifDrpt
        myCoordDrpt = coordDrpt
        myCatDrpt = catDrpt
        
        self.dropout_motifs = nn.Dropout(p=myMotifDrpt)
        self.dropout_coords = nn.Dropout(p=myCoordDrpt)
        self.dropout_cat = nn.Dropout(p=myCatDrpt)

    def forward(self, sentence, coords, version='seqCoord'):
        
#         print(sentence.shape, coords.shape)

        # motif CNN
        sentence = sentence.transpose(1,2).float()

        motif_conv1 = self.motif_conv1( sentence ) 
        motif_conv1 = self.relu( motif_conv1 )
        motif_conv1 = self.dropout_motifs( motif_conv1 )
        motif_conv2 = self.motif_conv2( motif_conv1 ) 
        motif_conv2 = self.relu( motif_conv2 )
        motif_conv2 = self.dropout_motifs( motif_conv2 )
        motif_conv3 = self.motif_conv3( motif_conv2 ) 
        motif_conv3 = self.relu( motif_conv3 )
        motif_conv3 = self.dropout_motifs( motif_conv3 )
        motif_conv3 = motif_conv3.reshape(motif_conv3.shape[0],motif_conv3.shape[1]*motif_conv3.shape[2])
                
        motif_fc1 = self.motif_fc1( motif_conv3 )
        motif_fc1 = self.bn0( motif_fc1 )
        motif_fc1 = self.relu( motif_fc1 )
        motif_fc1 = self.dropout_motifs( motif_fc1 )
        
        motif_fc2 = self.motif_fc2( motif_fc1 )
        motif_fc2 = self.bn0( motif_fc2 )
        motif_fc2 = self.relu( motif_fc2 )
        motif_out = self.dropout_motifs( motif_fc2 )
        
        # coords CNN 
        coords = coords.transpose(1,2).float()

#         print (coords.shape)   
        conv1 = self.conv1( coords ) 
        conv1 = self.relu( conv1 )
        conv1 = self.dropout_coords( conv1 )
#         print (conv1.shape)  
        conv2 = self.conv2( conv1 ) 
        conv2 = self.relu( conv2 )
        conv2 = self.dropout_coords( conv2 )
#         print (conv2.shape) 
        conv3 = self.conv3( conv2 ) 
        conv3 = self.relu( conv3 )
        conv3 = self.dropout_coords( conv3 )
#         print(conv3.shape)
        conv3 = conv3.reshape(conv3.shape[0],conv3.shape[1]*conv3.shape[2])
        
#         print(conv3.shape)

        fc1 = self.fc1( conv3 )
        fc1 = self.bn0( fc1 )
        fc1 = self.relu( fc1 )
        fc1 = self.dropout_coords( fc1 )
#         print(fc1.shape)
#         print("==============")
        
        fc1 = self.fc2( fc1 )
        fc1 = self.bn0( fc1 )
        fc1 = self.relu( fc1 )
        coords_out = self.dropout_coords( fc1 )
        

        # concat layers
        if version=='seqCoord':
            cat_init = torch.cat((motif_out, coords_out), 1)
        else: # motif-only version
            cat_init = torch.cat((motif_out, motif_out), 1) 
            
        cat_fc1 = self.cat_fc1(cat_init)
        cat_fc1 = self.bn0(cat_fc1)
        cat_fc1 = self.relu(cat_fc1)
        cat_fc1 = self.dropout_cat(cat_fc1)
        
#         cat_fc2 = self.cat_fc2(cat_fc1)
#         cat_fc2 = self.bn0(cat_fc2)
#         cat_fc2 = self.relu(cat_fc2)
#         cat_fc2 = self.dropout(cat_fc2)
        
        cat_out = self.cat_out( cat_fc1 )

        cat_sigmoid = self.sigmoid(cat_out)
   
        return cat_sigmoid

# %%
def train_model(model, optimizer, scheduler, num_epochs=25, 
                batch_size=32, myLoss='MSE', weighted='Weighted',stopper='ROC',
                thisVersion='seqCoord'):
    tLoss = []
    tRoc = []
    tPrc = []
    
    vLoss = []
    vRoc = []
    vPrc = []
    
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_roc = 0.0
    best_loss = 100000.0
    best_prc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)
        
        avg_running_roc = 0.0
        avg_best_roc = 0.0
        blah = 0
        
        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                
                train = data_utils.TensorDataset(features_train, target_train)
                train_loader = data_utils.DataLoader(train, batch_size=batch_size, 
                                                     shuffle=True, drop_last=True)

                if scheduler:
                    scheduler.step()
                model.train()  # Set model to training mode
            
            else:
                train = data_utils.TensorDataset(features_val, target_val)
                train_loader = data_utils.DataLoader(train, batch_size=len(idc_val), 
                                                     shuffle=True, drop_last=True)
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_roc = 0.0
            running_prc = 0.0

            # Iterate over data.
            poo = 0
            poo2 = 0
            for inputs, labels in train_loader:
                
                inputs = inputs.to(device)
                labels = labels.to(device)
                      
                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    sentence = inputs[:,:,:len(amino_acids)]
                    coords = inputs[:,:,len(amino_acids):]

                    outputs = model.forward(sentence=sentence, coords=coords, 
                                            version=thisVersion)
                    
                    
                    # three different losses 
                    if myLoss=='BCE':
                        criterion = nn.BCELoss()
                        loss = criterion(outputs, labels)
                    elif myLoss=='BCEphylo':
                        loss = BCE_phylo(outputs, labels) 
                    elif myLoss=='MSEphylo':
                        loss = MSE_phylo(outputs, labels) 
                    loss = loss.mean().float()
                        
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                y_test = numpy.array(labels.cpu())
                y_score = outputs.cpu().detach().numpy()
                roc = getMicroROC(y_test, y_score)
                prc = getPRC(y_test, y_score)
                
                # backpropagate loss
                running_loss += (loss.item() * inputs.size(0)) # * (1.0-roc)

                if not numpy.isnan(roc):
                    running_roc += roc
                    avg_running_roc += roc
                    poo+=1
                    blah+=1
                
                if not numpy.isnan(prc):
                    running_prc +=  prc
                    poo2+=1
                    
            epoch_loss = running_loss / len(train)
            epoch_roc = running_roc / poo
            epoch_prc = running_prc / poo2
            
            avg_epoch_roc = avg_running_roc / blah


            if phase =='train':
                tLoss.append(epoch_loss)
                tRoc.append(epoch_roc)
                tPrc.append(epoch_prc)
            else:
                vLoss.append(epoch_loss)
                vRoc.append(epoch_roc)
                vPrc.append(epoch_prc)
                
            avg_best_roc += avg_epoch_roc
                
            print('{} Loss: {:.4f}, ROC: {:.4f}, PRC: {:.4f}'.format(
                phase, epoch_loss, epoch_roc, epoch_prc))
            
            # choose between loss and roc metric
            if phase == 'val' and epoch_loss <= best_loss and epoch >= 50: # 5th epoch !!!
                best_loss = epoch_loss
                if stopper=='Loss':
                    best_model_wts = copy.deepcopy(model.state_dict())

            if phase == 'val' and epoch_roc >= best_roc and epoch >= 50: # 5th epoch !!!
                best_roc = epoch_roc
                if stopper=='ROC':
                    best_model_wts = copy.deepcopy(model.state_dict())
                                        
            if phase == 'val' and epoch_prc >= best_prc and epoch >= 50: # 5th epoch !!!
                best_prc = epoch_prc
                if stopper=='PRC':
                    best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val ROC: {:4f}'.format(best_roc))
    print('Best val PRC: {:4f}'.format(best_prc))
    print('Best val Loss: {:4f}'.format(best_loss))
    

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, tLoss, tRoc, vLoss, vRoc, best_roc

# %%
# def BCE_phylo(output, target):
    
#     weights = numpy.ones((output.shape[0],output.shape[1]))

#     for i,t in enumerate(target):
#         t = t.cpu()
#         wIdc = numpy.where(t.detach().numpy()==1)[0]

#         if len(wIdc)==0:
#             weights[i] = 0.000001
#             continue
#         theseWeights = numpy.ones((len(fams)))
#         for wIdx in wIdc:
#             thisWeight = famDistMatrix[wIdx].copy() # list of fam distances from true fam
#             thisWeight[wIdx] = 1.00 # true fam weight itself should be 1, want it to be the BIGGEST weight
#             theseWeights+=thisWeight # add to existing list of fam distances, respectively (element wise)
# #             print(theseWeights)
#         fWeight = theseWeights/len(fams) # take average
#         weights[i] = fWeight # if 1.00 - ... then am inverting
#     weights = torch.tensor(weights)
#     weights = weights.to(device)
    
#     crit = nn.BCELoss()
    
#     return crit(output, target)*((weights)).mean().float()

# %%
def MSE_phylo(output, target):
    
#     output = output.reshape(output.shape[0],output.shape[2],output.shape[1])
    
    weights = numpy.ones((output.shape[0],output.shape[1]))

    for i,t in enumerate(target):
        t = t.cpu()
        wIdc = numpy.where(t.detach().numpy()==1)[0]

        if len(wIdc)==0:
            weights[i] = 0.000001
            continue
        theseWeights = numpy.ones((len(fams)))
        for wIdx in wIdc:
            
            # want inter-fam weights to be distance (larger number, less related = more weight)
            thisWeight = famDistMatrix[wIdx].copy() # list of fam distances from true fam
            # want intra-fam weights to be similarity (larger number = more weight)
            thisWeight[wIdx] =  1.00 # - famDistMatrix[wIdx][wIdx].copy()
            theseWeights+=thisWeight # add to existing list of fam distances, respectively (element wise)
            
        fWeight = theseWeights/len(fams) # take average
        weights[i] = fWeight 
    weights = torch.tensor(weights)
    weights = weights.to(device)

    return (output.double()-target.double()+1e-6)**2.00*(weights.double()).mean().float()

#     return (output.double()-target.double()+1e-6)**2.00

# %%
from torch.optim import lr_scheduler
import time

BS = 256
tLoss1 = []
tAcc1 = []
vLoss1 = []
vAcc1 = []

totAcc = []
totY_score = []
totY_test = []

start = time.time()

###################################

motifDrpt = 0.5
coordDrpt = 0.5
catDrpt = 0.00

versionToUse = 'seqs' # '' 'seqCoord'
thisLoss = 'BCE'
# thisLoss = 'MSEphylo'
stopper = 'Loss' 
num_epochs = 1000


###################################


thisModel = Model(BS,motifDrpt,coordDrpt,catDrpt) 
thisModel = thisModel.to(device)
optimizer = optim.Adam(thisModel.parameters(),lr = 0.0015)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

myBestVal = 0
thisModel, tL, tA, vL, vA, myVal = train_model(thisModel, optimizer, False, 
                                             num_epochs=num_epochs, batch_size=BS, 
                                             myLoss=thisLoss, 
                                             weighted='not weighted',stopper=stopper,
                                             thisVersion=versionToUse)

if myVal >= myBestVal:
    myBestVal = myVal
    myBestModel = thisModel

tLoss1.append(tL)
tAcc1.append(tA)
vLoss1.append(vL)
vAcc1.append(vA)

print('\n - - - - - TIME: %s mins' % ((time.time() - start)/60.0),'- - - - -')
print ('\n - - - - - BEST VAL: ',myBestVal,'- - - - -')
    
(accuracy, y_score, y_test) = eval_model(myBestModel, thresh=0.5)
totAcc.append(accuracy)
totY_score.extend(y_score)
totY_test.extend(y_test)
# Out:
# Epoch 0/999
# ----------
# train Loss: 0.5395, ROC: 0.5465, PRC: 0.1735
# val Loss: 0.5836, ROC: 0.6127, PRC: 0.1973
#
# Epoch 1/999
# ----------
# train Loss: 0.4173, ROC: 0.5622, PRC: 0.1830
# val Loss: 0.5494, ROC: 0.6186, PRC: 0.2074
#
# Epoch 2/999
# ----------
# train Loss: 0.3892, ROC: 0.5976, PRC: 0.1892
# val Loss: 0.5131, ROC: 0.6239, PRC: 0.2215
#
# Epoch 3/999
# ----------
# train Loss: 0.3826, ROC: 0.6290, PRC: 0.2082
# val Loss: 0.5014, ROC: 0.6529, PRC: 0.2683
#
# Epoch 4/999
# ----------
# train Loss: 0.3654, ROC: 0.6890, PRC: 0.2848
# val Loss: 0.4972, ROC: 0.6656, PRC: 0.2910
#
# Epoch 5/999
# ----------
# train Loss: 0.3387, ROC: 0.7561, PRC: 0.3997
# val Loss: 0.4389, ROC: 0.7079, PRC: 0.3405
#
# Epoch 6/999
# ----------
# train Loss: 0.3123, ROC: 0.8084, PRC: 0.4800
# val Loss: 0.3992, ROC: 0.7203, PRC: 0.4028
#
# Epoch 7/999
# ----------
# train Loss: 0.2926, ROC: 0.8396, PRC: 0.5249
# val Loss: 0.3935, ROC: 0.7235, PRC: 0.4058
#
# Epoch 8/999
# ----------
# train Loss: 0.2842, ROC: 0.8506, PRC: 0.5357
# val Loss: 0.3911, ROC: 0.7292, PRC: 0.4068
#
# Epoch 9/999
# ----------
# train Loss: 0.2785, ROC: 0.8575, PRC: 0.5456
# val Loss: 0.3876, ROC: 0.7346, PRC: 0.3728
#
# Epoch 10/999
# ----------
# train Loss: 0.2754, ROC: 0.8619, PRC: 0.5529
# val Loss: 0.3821, ROC: 0.7382, PRC: 0.3697
#
# Epoch 11/999
# ----------
# train Loss: 0.2725, ROC: 0.8646, PRC: 0.5654
# val Loss: 0.3724, ROC: 0.7508, PRC: 0.4011
#
# Epoch 12/999
# ----------
# train Loss: 0.2658, ROC: 0.8738, PRC: 0.5849
# val Loss: 0.3521, ROC: 0.7858, PRC: 0.4556
#
# Epoch 13/999
# ----------
# train Loss: 0.2585, ROC: 0.8828, PRC: 0.6006
# val Loss: 0.3389, ROC: 0.8172, PRC: 0.5033
#
# Epoch 14/999
# ----------
# train Loss: 0.2544, ROC: 0.8882, PRC: 0.6112
# val Loss: 0.3288, ROC: 0.8257, PRC: 0.5131
#
# Epoch 15/999
# ----------
# train Loss: 0.2509, ROC: 0.8912, PRC: 0.6220
# val Loss: 0.3202, ROC: 0.8529, PRC: 0.5336
#
# Epoch 16/999
# ----------
# train Loss: 0.2481, ROC: 0.8946, PRC: 0.6283
# val Loss: 0.3114, ROC: 0.8576, PRC: 0.5287
#
# Epoch 17/999
# ----------
# train Loss: 0.2443, ROC: 0.8983, PRC: 0.6415
# val Loss: 0.3064, ROC: 0.8649, PRC: 0.5660
#
# Epoch 18/999
# ----------
# train Loss: 0.2436, ROC: 0.8992, PRC: 0.6391
# val Loss: 0.2996, ROC: 0.8719, PRC: 0.5920
#
# Epoch 19/999
# ----------
# train Loss: 0.2427, ROC: 0.8998, PRC: 0.6467
# val Loss: 0.2983, ROC: 0.8762, PRC: 0.6125
#
# Epoch 20/999
# ----------
# train Loss: 0.2423, ROC: 0.9000, PRC: 0.6469
# val Loss: 0.2986, ROC: 0.8705, PRC: 0.5988
#
# Epoch 21/999
# ----------
# train Loss: 0.2408, ROC: 0.9013, PRC: 0.6521
# val Loss: 0.2849, ROC: 0.8902, PRC: 0.6523
#
# Epoch 22/999
# ----------
# train Loss: 0.2381, ROC: 0.9045, PRC: 0.6608
# val Loss: 0.2773, ROC: 0.8929, PRC: 0.6666
#
# Epoch 23/999
# ----------
# train Loss: 0.2370, ROC: 0.9042, PRC: 0.6655
# val Loss: 0.2828, ROC: 0.8909, PRC: 0.6635
#
# Epoch 24/999
# ----------
# train Loss: 0.2356, ROC: 0.9062, PRC: 0.6669
# val Loss: 0.2815, ROC: 0.8888, PRC: 0.6507
#
# Epoch 25/999
# ----------
# train Loss: 0.2354, ROC: 0.9067, PRC: 0.6663
# val Loss: 0.2803, ROC: 0.8925, PRC: 0.6657
#
# Epoch 26/999
# ----------
# train Loss: 0.2356, ROC: 0.9055, PRC: 0.6673
# val Loss: 0.2830, ROC: 0.8934, PRC: 0.6644
#
# Epoch 27/999
# ----------
# train Loss: 0.2335, ROC: 0.9080, PRC: 0.6726
# val Loss: 0.2755, ROC: 0.8921, PRC: 0.6629
#
# Epoch 28/999
# ----------
# train Loss: 0.2339, ROC: 0.9076, PRC: 0.6734
# val Loss: 0.2749, ROC: 0.8944, PRC: 0.6746
#
# Epoch 29/999
# ----------
# train Loss: 0.2329, ROC: 0.9084, PRC: 0.6747
# val Loss: 0.2755, ROC: 0.8931, PRC: 0.6733
#
# Epoch 30/999
# ----------
# train Loss: 0.2310, ROC: 0.9099, PRC: 0.6801
# val Loss: 0.2712, ROC: 0.8993, PRC: 0.6900
#
# Epoch 31/999
# ----------
# train Loss: 0.2301, ROC: 0.9113, PRC: 0.6846
# val Loss: 0.2708, ROC: 0.9003, PRC: 0.6999
#
# Epoch 32/999
# ----------
# train Loss: 0.2301, ROC: 0.9106, PRC: 0.6814
# val Loss: 0.2728, ROC: 0.8974, PRC: 0.6877
#
# Epoch 33/999
# ----------
# train Loss: 0.2292, ROC: 0.9119, PRC: 0.6860
# val Loss: 0.2712, ROC: 0.8971, PRC: 0.6891
#
# Epoch 34/999
# ----------
# train Loss: 0.2287, ROC: 0.9119, PRC: 0.6865
# val Loss: 0.2722, ROC: 0.8976, PRC: 0.6909
#
# Epoch 35/999
# ----------
# train Loss: 0.2288, ROC: 0.9115, PRC: 0.6860
# val Loss: 0.2747, ROC: 0.8977, PRC: 0.6935
#
# Epoch 36/999
# ----------
# train Loss: 0.2269, ROC: 0.9137, PRC: 0.6923
# val Loss: 0.2666, ROC: 0.9023, PRC: 0.7055
#
# Epoch 37/999
# ----------
# train Loss: 0.2261, ROC: 0.9146, PRC: 0.6932
# val Loss: 0.2689, ROC: 0.9014, PRC: 0.7062
#
# Epoch 38/999
# ----------
# train Loss: 0.2275, ROC: 0.9133, PRC: 0.6896
# val Loss: 0.2678, ROC: 0.9053, PRC: 0.7095
#
# Epoch 39/999
# ----------
# train Loss: 0.2257, ROC: 0.9142, PRC: 0.6933
# val Loss: 0.2683, ROC: 0.9055, PRC: 0.7081
#
# Epoch 40/999
# ----------
# train Loss: 0.2272, ROC: 0.9136, PRC: 0.6928
# val Loss: 0.2661, ROC: 0.9066, PRC: 0.7149
#
# Epoch 41/999
# ----------
# train Loss: 0.2249, ROC: 0.9149, PRC: 0.6951
# val Loss: 0.2663, ROC: 0.9039, PRC: 0.7084
#
# Epoch 42/999
# ----------
# train Loss: 0.2238, ROC: 0.9161, PRC: 0.6991
# val Loss: 0.2672, ROC: 0.9016, PRC: 0.6971
#
# Epoch 43/999
# ----------
# train Loss: 0.2251, ROC: 0.9152, PRC: 0.6962
# val Loss: 0.2661, ROC: 0.9043, PRC: 0.7066
#
# Epoch 44/999
# ----------
# train Loss: 0.2223, ROC: 0.9179, PRC: 0.7016
# val Loss: 0.2637, ROC: 0.9066, PRC: 0.7102
#
# Epoch 45/999
# ----------
# train Loss: 0.2213, ROC: 0.9182, PRC: 0.7077
# val Loss: 0.2645, ROC: 0.9036, PRC: 0.7067
#
# Epoch 46/999
# ----------
# train Loss: 0.2216, ROC: 0.9173, PRC: 0.7057
# val Loss: 0.2715, ROC: 0.8978, PRC: 0.6967
#
# Epoch 47/999
# ----------
# train Loss: 0.2234, ROC: 0.9161, PRC: 0.7012
# val Loss: 0.2716, ROC: 0.8972, PRC: 0.6964
#
# Epoch 48/999
# ----------
# train Loss: 0.2232, ROC: 0.9165, PRC: 0.6993
# val Loss: 0.2707, ROC: 0.9028, PRC: 0.7019
#
# Epoch 49/999
# ----------
# train Loss: 0.2214, ROC: 0.9179, PRC: 0.7062
# val Loss: 0.2687, ROC: 0.9067, PRC: 0.7139
#
# Epoch 50/999
# ----------
# train Loss: 0.2210, ROC: 0.9180, PRC: 0.7048
# val Loss: 0.2672, ROC: 0.9074, PRC: 0.7149
#
# Epoch 51/999
# ----------
# train Loss: 0.2209, ROC: 0.9190, PRC: 0.7096
# val Loss: 0.2676, ROC: 0.9077, PRC: 0.7122
#
# Epoch 52/999
# ----------
# train Loss: 0.2197, ROC: 0.9192, PRC: 0.7107
# val Loss: 0.2691, ROC: 0.9059, PRC: 0.7054
#
# Epoch 53/999
# ----------
# train Loss: 0.2157, ROC: 0.9223, PRC: 0.7170
# val Loss: 0.2681, ROC: 0.9100, PRC: 0.7146
#
# Epoch 54/999
# ----------
# train Loss: 0.2177, ROC: 0.9205, PRC: 0.7161
# val Loss: 0.2638, ROC: 0.9078, PRC: 0.7053
#
# Epoch 55/999
# ----------
# train Loss: 0.2186, ROC: 0.9203, PRC: 0.7135
# val Loss: 0.2628, ROC: 0.9116, PRC: 0.7144
#
# Epoch 56/999
# ----------
# train Loss: 0.2175, ROC: 0.9208, PRC: 0.7159
# val Loss: 0.2633, ROC: 0.9114, PRC: 0.7130
#
# Epoch 57/999
# ----------
# train Loss: 0.2152, ROC: 0.9228, PRC: 0.7211
# val Loss: 0.2624, ROC: 0.9119, PRC: 0.7161
#
# Epoch 58/999
# ----------
# train Loss: 0.2163, ROC: 0.9216, PRC: 0.7190
# val Loss: 0.2607, ROC: 0.9138, PRC: 0.7176
#
# Epoch 59/999
# ----------
# train Loss: 0.2158, ROC: 0.9224, PRC: 0.7208
# val Loss: 0.2636, ROC: 0.9140, PRC: 0.7164
#
# Epoch 60/999
# ----------
# train Loss: 0.2155, ROC: 0.9222, PRC: 0.7201
# val Loss: 0.2691, ROC: 0.9154, PRC: 0.7157
#
# Epoch 61/999
# ----------
# train Loss: 0.2162, ROC: 0.9222, PRC: 0.7183
# val Loss: 0.2645, ROC: 0.9167, PRC: 0.7185
#
# Epoch 62/999
# ----------
# train Loss: 0.2163, ROC: 0.9218, PRC: 0.7168
# val Loss: 0.2620, ROC: 0.9166, PRC: 0.7200
#
# Epoch 63/999
# ----------
# train Loss: 0.2167, ROC: 0.9215, PRC: 0.7168
# val Loss: 0.2642, ROC: 0.9163, PRC: 0.7193
#
# Epoch 64/999
# ----------
# train Loss: 0.2145, ROC: 0.9230, PRC: 0.7224
# val Loss: 0.2608, ROC: 0.9167, PRC: 0.7213
#
# Epoch 65/999
# ----------
# train Loss: 0.2149, ROC: 0.9233, PRC: 0.7227
# val Loss: 0.2585, ROC: 0.9193, PRC: 0.7275
#
# Epoch 66/999
# ----------
# train Loss: 0.2140, ROC: 0.9235, PRC: 0.7239
# val Loss: 0.2579, ROC: 0.9176, PRC: 0.7210
#
# Epoch 67/999
# ----------
# train Loss: 0.2153, ROC: 0.9231, PRC: 0.7236
# val Loss: 0.2560, ROC: 0.9188, PRC: 0.7240
#
# Epoch 68/999
# ----------
# train Loss: 0.2140, ROC: 0.9235, PRC: 0.7225
# val Loss: 0.2597, ROC: 0.9181, PRC: 0.7191
#
# Epoch 69/999
# ----------
# train Loss: 0.2150, ROC: 0.9229, PRC: 0.7243
# val Loss: 0.2577, ROC: 0.9210, PRC: 0.7234
#
# Epoch 70/999
# ----------
# train Loss: 0.2150, ROC: 0.9224, PRC: 0.7214
# val Loss: 0.2572, ROC: 0.9216, PRC: 0.7277
#
# Epoch 71/999
# ----------
# train Loss: 0.2126, ROC: 0.9249, PRC: 0.7269
# val Loss: 0.2579, ROC: 0.9196, PRC: 0.7219
#
# Epoch 72/999
# ----------
# train Loss: 0.2131, ROC: 0.9240, PRC: 0.7263
# val Loss: 0.2572, ROC: 0.9192, PRC: 0.7190
#
# Epoch 73/999
# ----------
# train Loss: 0.2120, ROC: 0.9256, PRC: 0.7278
# val Loss: 0.2601, ROC: 0.9207, PRC: 0.7250
#
# Epoch 74/999
# ----------
# train Loss: 0.2133, ROC: 0.9239, PRC: 0.7269
# val Loss: 0.2585, ROC: 0.9213, PRC: 0.7255
#
# Epoch 75/999
# ----------
# train Loss: 0.2140, ROC: 0.9238, PRC: 0.7234
# val Loss: 0.2603, ROC: 0.9211, PRC: 0.7242
#
# Epoch 76/999
# ----------
# train Loss: 0.2127, ROC: 0.9247, PRC: 0.7275
# val Loss: 0.2653, ROC: 0.9189, PRC: 0.7155
#
# Epoch 77/999
# ----------
# train Loss: 0.2132, ROC: 0.9240, PRC: 0.7277
# val Loss: 0.2603, ROC: 0.9209, PRC: 0.7214
#
# Epoch 78/999
# ----------
# train Loss: 0.2104, ROC: 0.9269, PRC: 0.7336
# val Loss: 0.2605, ROC: 0.9218, PRC: 0.7261
#
# Epoch 79/999
# ----------
# train Loss: 0.2113, ROC: 0.9260, PRC: 0.7290
# val Loss: 0.2594, ROC: 0.9203, PRC: 0.7208
#
# Epoch 80/999
# ----------
# train Loss: 0.2142, ROC: 0.9231, PRC: 0.7258
# val Loss: 0.2598, ROC: 0.9207, PRC: 0.7236
#
# Epoch 81/999
# ----------
# train Loss: 0.2107, ROC: 0.9265, PRC: 0.7315
# val Loss: 0.2583, ROC: 0.9225, PRC: 0.7286
#
# Epoch 82/999
# ----------
# train Loss: 0.2107, ROC: 0.9265, PRC: 0.7303
# val Loss: 0.2597, ROC: 0.9225, PRC: 0.7284
#
# Epoch 83/999
# ----------
# train Loss: 0.2098, ROC: 0.9270, PRC: 0.7340
# val Loss: 0.2619, ROC: 0.9176, PRC: 0.7139
#
# Epoch 84/999
# ----------
# train Loss: 0.2102, ROC: 0.9268, PRC: 0.7334
# val Loss: 0.2635, ROC: 0.9213, PRC: 0.7236
#
# Epoch 85/999
# ----------
# train Loss: 0.2113, ROC: 0.9258, PRC: 0.7294
# val Loss: 0.2611, ROC: 0.9190, PRC: 0.7174
#
# Epoch 86/999
# ----------
# train Loss: 0.2113, ROC: 0.9262, PRC: 0.7311
# val Loss: 0.2576, ROC: 0.9222, PRC: 0.7280
#
# Epoch 87/999
# ----------
# train Loss: 0.2115, ROC: 0.9254, PRC: 0.7291
# val Loss: 0.2604, ROC: 0.9208, PRC: 0.7233
#
# Epoch 88/999
# ----------
# train Loss: 0.2102, ROC: 0.9266, PRC: 0.7352
# val Loss: 0.2552, ROC: 0.9234, PRC: 0.7313
#
# Epoch 89/999
# ----------
# train Loss: 0.2096, ROC: 0.9269, PRC: 0.7354
# val Loss: 0.2580, ROC: 0.9212, PRC: 0.7244
#
# Epoch 90/999
# ----------
# train Loss: 0.2119, ROC: 0.9257, PRC: 0.7298
# val Loss: 0.2593, ROC: 0.9215, PRC: 0.7247
#
# Epoch 91/999
# ----------
# train Loss: 0.2100, ROC: 0.9273, PRC: 0.7320
# val Loss: 0.2581, ROC: 0.9223, PRC: 0.7250
#
# Epoch 92/999
# ----------
# train Loss: 0.2101, ROC: 0.9265, PRC: 0.7360
# val Loss: 0.2605, ROC: 0.9200, PRC: 0.7189
#
# Epoch 93/999
# ----------
# train Loss: 0.2083, ROC: 0.9283, PRC: 0.7404
# val Loss: 0.2604, ROC: 0.9209, PRC: 0.7212
#
# Epoch 94/999
# ----------
# train Loss: 0.2110, ROC: 0.9261, PRC: 0.7346
# val Loss: 0.2570, ROC: 0.9220, PRC: 0.7276
#
# Epoch 95/999
# ----------
# train Loss: 0.2084, ROC: 0.9274, PRC: 0.7399
# val Loss: 0.2606, ROC: 0.9213, PRC: 0.7224
#
# Epoch 96/999
# ----------
# train Loss: 0.2099, ROC: 0.9269, PRC: 0.7350
# val Loss: 0.2617, ROC: 0.9201, PRC: 0.7231
#
# Epoch 97/999
# ----------
# train Loss: 0.2081, ROC: 0.9286, PRC: 0.7373
# val Loss: 0.2591, ROC: 0.9214, PRC: 0.7251
#
# Epoch 98/999
# ----------
# train Loss: 0.2073, ROC: 0.9285, PRC: 0.7416
# val Loss: 0.2580, ROC: 0.9219, PRC: 0.7244
#
# Epoch 99/999
# ----------
# train Loss: 0.2076, ROC: 0.9284, PRC: 0.7407
# val Loss: 0.2560, ROC: 0.9228, PRC: 0.7283
#
# Epoch 100/999
# ----------
# train Loss: 0.2089, ROC: 0.9273, PRC: 0.7386
# val Loss: 0.2552, ROC: 0.9244, PRC: 0.7338
#
# Epoch 101/999
# ----------
# train Loss: 0.2089, ROC: 0.9279, PRC: 0.7374
# val Loss: 0.2553, ROC: 0.9255, PRC: 0.7355
#
# Epoch 102/999
# ----------
# train Loss: 0.2095, ROC: 0.9268, PRC: 0.7360
# val Loss: 0.2636, ROC: 0.9191, PRC: 0.7163
#
# Epoch 103/999
# ----------
# train Loss: 0.2085, ROC: 0.9282, PRC: 0.7381
# val Loss: 0.2551, ROC: 0.9213, PRC: 0.7244
#
# Epoch 104/999
# ----------
# train Loss: 0.2084, ROC: 0.9286, PRC: 0.7362
# val Loss: 0.2586, ROC: 0.9203, PRC: 0.7227
#
# Epoch 105/999
# ----------
# train Loss: 0.2068, ROC: 0.9295, PRC: 0.7429
# val Loss: 0.2585, ROC: 0.9213, PRC: 0.7247
#
# Epoch 106/999
# ----------
# train Loss: 0.2087, ROC: 0.9281, PRC: 0.7363
# val Loss: 0.2535, ROC: 0.9224, PRC: 0.7293
#
# Epoch 107/999
# ----------
# train Loss: 0.2080, ROC: 0.9287, PRC: 0.7397
# val Loss: 0.2556, ROC: 0.9211, PRC: 0.7229
#
# Epoch 108/999
# ----------
# train Loss: 0.2073, ROC: 0.9289, PRC: 0.7405
# val Loss: 0.2571, ROC: 0.9198, PRC: 0.7195
#
# Epoch 109/999
# ----------
# train Loss: 0.2086, ROC: 0.9279, PRC: 0.7377
# val Loss: 0.2598, ROC: 0.9202, PRC: 0.7209
#
# Epoch 110/999
# ----------
# train Loss: 0.2091, ROC: 0.9275, PRC: 0.7355
# val Loss: 0.2526, ROC: 0.9245, PRC: 0.7331
#
# Epoch 111/999
# ----------
# train Loss: 0.2088, ROC: 0.9282, PRC: 0.7380
# val Loss: 0.2582, ROC: 0.9233, PRC: 0.7320
#
# Epoch 112/999
# ----------
# train Loss: 0.2083, ROC: 0.9274, PRC: 0.7406
# val Loss: 0.2565, ROC: 0.9252, PRC: 0.7384
#
# Epoch 113/999
# ----------
# train Loss: 0.2068, ROC: 0.9286, PRC: 0.7427
# val Loss: 0.2526, ROC: 0.9245, PRC: 0.7337
#
# Epoch 114/999
# ----------
# train Loss: 0.2072, ROC: 0.9292, PRC: 0.7421
# val Loss: 0.2559, ROC: 0.9245, PRC: 0.7328
#
# Epoch 115/999
# ----------
# train Loss: 0.2048, ROC: 0.9306, PRC: 0.7467
# val Loss: 0.2561, ROC: 0.9218, PRC: 0.7249
#
# Epoch 116/999
# ----------
# train Loss: 0.2070, ROC: 0.9286, PRC: 0.7406
# val Loss: 0.2585, ROC: 0.9214, PRC: 0.7216
#
# Epoch 117/999
# ----------
# train Loss: 0.2062, ROC: 0.9295, PRC: 0.7431
# val Loss: 0.2544, ROC: 0.9248, PRC: 0.7324
#
# Epoch 118/999
# ----------
# train Loss: 0.2058, ROC: 0.9298, PRC: 0.7451
# val Loss: 0.2526, ROC: 0.9230, PRC: 0.7289
#
# Epoch 119/999
# ----------
# train Loss: 0.2077, ROC: 0.9279, PRC: 0.7399
# val Loss: 0.2540, ROC: 0.9237, PRC: 0.7311
#
# Epoch 120/999
# ----------
# train Loss: 0.2058, ROC: 0.9301, PRC: 0.7457
# val Loss: 0.2577, ROC: 0.9214, PRC: 0.7212
#
# Epoch 121/999
# ----------
# train Loss: 0.2078, ROC: 0.9280, PRC: 0.7401
# val Loss: 0.2553, ROC: 0.9242, PRC: 0.7294
#
# Epoch 122/999
# ----------
# train Loss: 0.2069, ROC: 0.9291, PRC: 0.7426
# val Loss: 0.2519, ROC: 0.9243, PRC: 0.7317
#
# Epoch 123/999
# ----------
# train Loss: 0.2058, ROC: 0.9303, PRC: 0.7446
# val Loss: 0.2545, ROC: 0.9245, PRC: 0.7305
#
# Epoch 124/999
# ----------
# train Loss: 0.2057, ROC: 0.9297, PRC: 0.7451
# val Loss: 0.2516, ROC: 0.9243, PRC: 0.7316
#
# Epoch 125/999
# ----------
# train Loss: 0.2067, ROC: 0.9291, PRC: 0.7436
# val Loss: 0.2563, ROC: 0.9229, PRC: 0.7296
#
# Epoch 126/999
# ----------
# train Loss: 0.2053, ROC: 0.9303, PRC: 0.7452
# val Loss: 0.2574, ROC: 0.9226, PRC: 0.7281
#
# Epoch 127/999
# ----------
# train Loss: 0.2060, ROC: 0.9293, PRC: 0.7456
# val Loss: 0.2531, ROC: 0.9216, PRC: 0.7276
#
# Epoch 128/999
# ----------
# train Loss: 0.2068, ROC: 0.9295, PRC: 0.7419
# val Loss: 0.2556, ROC: 0.9217, PRC: 0.7263
#
# Epoch 129/999
# ----------
# train Loss: 0.2051, ROC: 0.9307, PRC: 0.7439
# val Loss: 0.2552, ROC: 0.9215, PRC: 0.7228
#
# Epoch 130/999
# ----------
# train Loss: 0.2039, ROC: 0.9313, PRC: 0.7473
# val Loss: 0.2557, ROC: 0.9226, PRC: 0.7288
#
# Epoch 131/999
# ----------
# train Loss: 0.2049, ROC: 0.9309, PRC: 0.7477
# val Loss: 0.2562, ROC: 0.9231, PRC: 0.7293
#
# Epoch 132/999
# ----------
# train Loss: 0.2059, ROC: 0.9295, PRC: 0.7453
# val Loss: 0.2548, ROC: 0.9232, PRC: 0.7316
#
# Epoch 133/999
# ----------
# train Loss: 0.2055, ROC: 0.9302, PRC: 0.7459
# val Loss: 0.2518, ROC: 0.9234, PRC: 0.7313
#
# Epoch 134/999
# ----------
# train Loss: 0.2048, ROC: 0.9305, PRC: 0.7464
# val Loss: 0.2547, ROC: 0.9236, PRC: 0.7311
#
# Epoch 135/999
# ----------
# train Loss: 0.2053, ROC: 0.9303, PRC: 0.7448
# val Loss: 0.2570, ROC: 0.9243, PRC: 0.7342
#
# Epoch 136/999
# ----------
# train Loss: 0.2055, ROC: 0.9303, PRC: 0.7456
# val Loss: 0.2505, ROC: 0.9248, PRC: 0.7352
#
# Epoch 137/999
# ----------
# train Loss: 0.2043, ROC: 0.9310, PRC: 0.7498
# val Loss: 0.2522, ROC: 0.9234, PRC: 0.7314
#
# Epoch 138/999
# ----------
# train Loss: 0.2038, ROC: 0.9311, PRC: 0.7501
# val Loss: 0.2552, ROC: 0.9221, PRC: 0.7265
#
# Epoch 139/999
# ----------
# train Loss: 0.2058, ROC: 0.9298, PRC: 0.7443
# val Loss: 0.2605, ROC: 0.9218, PRC: 0.7261
#
# Epoch 140/999
# ----------
# train Loss: 0.2075, ROC: 0.9289, PRC: 0.7403
# val Loss: 0.2592, ROC: 0.9228, PRC: 0.7293
#
# Epoch 141/999
# ----------
# train Loss: 0.2037, ROC: 0.9314, PRC: 0.7494
# val Loss: 0.2556, ROC: 0.9215, PRC: 0.7258
#
# Epoch 142/999
# ----------
# train Loss: 0.2040, ROC: 0.9315, PRC: 0.7491
# val Loss: 0.2572, ROC: 0.9193, PRC: 0.7177
#
# Epoch 143/999
# ----------
# train Loss: 0.2058, ROC: 0.9301, PRC: 0.7455
# val Loss: 0.2564, ROC: 0.9189, PRC: 0.7167
#
# Epoch 144/999
# ----------
# train Loss: 0.2042, ROC: 0.9307, PRC: 0.7483
# val Loss: 0.2598, ROC: 0.9221, PRC: 0.7252
#
# Epoch 145/999
# ----------
# train Loss: 0.2046, ROC: 0.9313, PRC: 0.7454
# val Loss: 0.2552, ROC: 0.9217, PRC: 0.7248
#
# Epoch 146/999
# ----------
# train Loss: 0.2034, ROC: 0.9320, PRC: 0.7490
# val Loss: 0.2524, ROC: 0.9213, PRC: 0.7218
#
# Epoch 147/999
# ----------
# train Loss: 0.2068, ROC: 0.9294, PRC: 0.7420
# val Loss: 0.2564, ROC: 0.9203, PRC: 0.7189
#
# Epoch 148/999
# ----------
# train Loss: 0.2029, ROC: 0.9313, PRC: 0.7523
# val Loss: 0.2569, ROC: 0.9218, PRC: 0.7254
#
# Epoch 149/999
# ----------
# train Loss: 0.2020, ROC: 0.9324, PRC: 0.7533
# val Loss: 0.2549, ROC: 0.9224, PRC: 0.7263
#
# Epoch 150/999
# ----------
# train Loss: 0.2067, ROC: 0.9298, PRC: 0.7417
# val Loss: 0.2541, ROC: 0.9222, PRC: 0.7237
#
# Epoch 151/999
# ----------
# train Loss: 0.2060, ROC: 0.9302, PRC: 0.7446
# val Loss: 0.2567, ROC: 0.9229, PRC: 0.7269
#
# Epoch 152/999
# ----------
# train Loss: 0.2048, ROC: 0.9306, PRC: 0.7467
# val Loss: 0.2546, ROC: 0.9221, PRC: 0.7232
#
# Epoch 153/999
# ----------
# train Loss: 0.2040, ROC: 0.9319, PRC: 0.7495
# val Loss: 0.2583, ROC: 0.9246, PRC: 0.7311
#
# Epoch 154/999
# ----------
# train Loss: 0.2057, ROC: 0.9300, PRC: 0.7448
# val Loss: 0.2561, ROC: 0.9244, PRC: 0.7333
#
# Epoch 155/999
# ----------
# train Loss: 0.2045, ROC: 0.9309, PRC: 0.7473
# val Loss: 0.2563, ROC: 0.9236, PRC: 0.7289
#
# Epoch 156/999
# ----------
# train Loss: 0.2071, ROC: 0.9295, PRC: 0.7403
# val Loss: 0.2547, ROC: 0.9223, PRC: 0.7268
#
# Epoch 157/999
# ----------
# train Loss: 0.2038, ROC: 0.9317, PRC: 0.7488
# val Loss: 0.2543, ROC: 0.9232, PRC: 0.7256
#
# Epoch 158/999
# ----------
# train Loss: 0.2057, ROC: 0.9299, PRC: 0.7446
# val Loss: 0.2511, ROC: 0.9225, PRC: 0.7234
#
# Epoch 159/999
# ----------
# train Loss: 0.2043, ROC: 0.9315, PRC: 0.7472
# val Loss: 0.2553, ROC: 0.9209, PRC: 0.7174
#
# Epoch 160/999
# ----------
# train Loss: 0.2040, ROC: 0.9318, PRC: 0.7491
# val Loss: 0.2554, ROC: 0.9229, PRC: 0.7262
#
# Epoch 161/999
# ----------
# train Loss: 0.2040, ROC: 0.9309, PRC: 0.7499
# val Loss: 0.2505, ROC: 0.9216, PRC: 0.7215
#
# Epoch 162/999
# ----------
# train Loss: 0.2032, ROC: 0.9322, PRC: 0.7511
# val Loss: 0.2565, ROC: 0.9206, PRC: 0.7193
#
# Epoch 163/999
# ----------
# train Loss: 0.2012, ROC: 0.9334, PRC: 0.7551
# val Loss: 0.2531, ROC: 0.9224, PRC: 0.7224
#
# Epoch 164/999
# ----------
# train Loss: 0.2054, ROC: 0.9299, PRC: 0.7454
# val Loss: 0.2564, ROC: 0.9196, PRC: 0.7164
#
# Epoch 165/999
# ----------
# train Loss: 0.2026, ROC: 0.9325, PRC: 0.7521
# val Loss: 0.2557, ROC: 0.9205, PRC: 0.7187
#
# Epoch 166/999
# ----------
# train Loss: 0.2055, ROC: 0.9303, PRC: 0.7466
# val Loss: 0.2538, ROC: 0.9224, PRC: 0.7264
#
# Epoch 167/999
# ----------
# train Loss: 0.2040, ROC: 0.9310, PRC: 0.7498
# val Loss: 0.2557, ROC: 0.9211, PRC: 0.7215
#
# Epoch 168/999
# ----------
# train Loss: 0.2028, ROC: 0.9317, PRC: 0.7531
# val Loss: 0.2533, ROC: 0.9210, PRC: 0.7191
#
# Epoch 169/999
# ----------
# train Loss: 0.2028, ROC: 0.9326, PRC: 0.7491
# val Loss: 0.2544, ROC: 0.9216, PRC: 0.7222
#
# Epoch 170/999
# ----------
# train Loss: 0.2033, ROC: 0.9315, PRC: 0.7508
# val Loss: 0.2519, ROC: 0.9235, PRC: 0.7280
#
# Epoch 171/999
# ----------
# train Loss: 0.2035, ROC: 0.9318, PRC: 0.7492
# val Loss: 0.2573, ROC: 0.9226, PRC: 0.7239
#
# Epoch 172/999
# ----------
# train Loss: 0.2018, ROC: 0.9326, PRC: 0.7563
# val Loss: 0.2531, ROC: 0.9226, PRC: 0.7258
#
# Epoch 173/999
# ----------
# train Loss: 0.2031, ROC: 0.9320, PRC: 0.7499
# val Loss: 0.2550, ROC: 0.9221, PRC: 0.7268
#
# Epoch 174/999
# ----------
# train Loss: 0.2011, ROC: 0.9330, PRC: 0.7548
# val Loss: 0.2539, ROC: 0.9211, PRC: 0.7219
#
# Epoch 175/999
# ----------
# train Loss: 0.2031, ROC: 0.9322, PRC: 0.7503
# val Loss: 0.2523, ROC: 0.9223, PRC: 0.7257
#
# Epoch 176/999
# ----------
# train Loss: 0.2038, ROC: 0.9315, PRC: 0.7499
# val Loss: 0.2523, ROC: 0.9221, PRC: 0.7237
#
# Epoch 177/999
# ----------
# train Loss: 0.2031, ROC: 0.9318, PRC: 0.7519
# val Loss: 0.2525, ROC: 0.9235, PRC: 0.7281
#
# Epoch 178/999
# ----------
# train Loss: 0.2010, ROC: 0.9342, PRC: 0.7524
# val Loss: 0.2523, ROC: 0.9199, PRC: 0.7184
#
# Epoch 179/999
# ----------
# train Loss: 0.2031, ROC: 0.9318, PRC: 0.7513
# val Loss: 0.2585, ROC: 0.9176, PRC: 0.7097
#
# Epoch 180/999
# ----------
# train Loss: 0.2034, ROC: 0.9316, PRC: 0.7497
# val Loss: 0.2544, ROC: 0.9204, PRC: 0.7174
#
# Epoch 181/999
# ----------
# train Loss: 0.2015, ROC: 0.9332, PRC: 0.7554
# val Loss: 0.2537, ROC: 0.9216, PRC: 0.7208
#
# Epoch 182/999
# ----------
# train Loss: 0.2013, ROC: 0.9328, PRC: 0.7560
# val Loss: 0.2499, ROC: 0.9225, PRC: 0.7256
#
# Epoch 183/999
# ----------
# train Loss: 0.2032, ROC: 0.9320, PRC: 0.7491
# val Loss: 0.2524, ROC: 0.9224, PRC: 0.7243
#
# Epoch 184/999
# ----------
# train Loss: 0.2020, ROC: 0.9330, PRC: 0.7533
# val Loss: 0.2537, ROC: 0.9208, PRC: 0.7174
#
# Epoch 185/999
# ----------
# train Loss: 0.2037, ROC: 0.9316, PRC: 0.7511
# val Loss: 0.2541, ROC: 0.9190, PRC: 0.7152
#
# Epoch 186/999
# ----------
# train Loss: 0.2022, ROC: 0.9326, PRC: 0.7522
# val Loss: 0.2584, ROC: 0.9192, PRC: 0.7137
#
# Epoch 187/999
# ----------
# train Loss: 0.2040, ROC: 0.9312, PRC: 0.7486
# val Loss: 0.2560, ROC: 0.9216, PRC: 0.7233
#
# Epoch 188/999
# ----------
# train Loss: 0.2022, ROC: 0.9326, PRC: 0.7543
# val Loss: 0.2586, ROC: 0.9197, PRC: 0.7174
#
# Epoch 189/999
# ----------
# train Loss: 0.2031, ROC: 0.9315, PRC: 0.7518
# val Loss: 0.2562, ROC: 0.9217, PRC: 0.7259
#
# Epoch 190/999
# ----------
# train Loss: 0.2036, ROC: 0.9319, PRC: 0.7502
# val Loss: 0.2531, ROC: 0.9221, PRC: 0.7259
#
# Epoch 191/999
# ----------
# train Loss: 0.2034, ROC: 0.9313, PRC: 0.7505
# val Loss: 0.2535, ROC: 0.9240, PRC: 0.7332
#
# Epoch 192/999
# ----------
# train Loss: 0.2030, ROC: 0.9317, PRC: 0.7520
# val Loss: 0.2548, ROC: 0.9218, PRC: 0.7243
#
# Epoch 193/999
# ----------
# train Loss: 0.2021, ROC: 0.9328, PRC: 0.7534
# val Loss: 0.2469, ROC: 0.9242, PRC: 0.7315
#
# Epoch 194/999
# ----------
# train Loss: 0.2031, ROC: 0.9318, PRC: 0.7512
# val Loss: 0.2506, ROC: 0.9233, PRC: 0.7293
#
# Epoch 195/999
# ----------
# train Loss: 0.2010, ROC: 0.9331, PRC: 0.7564
# val Loss: 0.2495, ROC: 0.9239, PRC: 0.7333
#
# Epoch 196/999
# ----------
# train Loss: 0.2002, ROC: 0.9340, PRC: 0.7592
# val Loss: 0.2482, ROC: 0.9228, PRC: 0.7250
#
# Epoch 197/999
# ----------
# train Loss: 0.1993, ROC: 0.9347, PRC: 0.7582
# val Loss: 0.2551, ROC: 0.9222, PRC: 0.7252
#
# Epoch 198/999
# ----------
# train Loss: 0.1997, ROC: 0.9344, PRC: 0.7570
# val Loss: 0.2500, ROC: 0.9230, PRC: 0.7285
#
# Epoch 199/999
# ----------
# train Loss: 0.2019, ROC: 0.9328, PRC: 0.7540
# val Loss: 0.2495, ROC: 0.9220, PRC: 0.7219
#
# Epoch 200/999
# ----------
# train Loss: 0.2037, ROC: 0.9313, PRC: 0.7502
# val Loss: 0.2552, ROC: 0.9220, PRC: 0.7226
#
# Epoch 201/999
# ----------
# train Loss: 0.2040, ROC: 0.9311, PRC: 0.7484
# val Loss: 0.2518, ROC: 0.9223, PRC: 0.7229
#
# Epoch 202/999
# ----------
# train Loss: 0.2024, ROC: 0.9326, PRC: 0.7523
# val Loss: 0.2484, ROC: 0.9257, PRC: 0.7361
#
# Epoch 203/999
# ----------
# train Loss: 0.2010, ROC: 0.9335, PRC: 0.7560
# val Loss: 0.2516, ROC: 0.9245, PRC: 0.7293
#
# Epoch 204/999
# ----------
# train Loss: 0.2026, ROC: 0.9325, PRC: 0.7529
# val Loss: 0.2544, ROC: 0.9222, PRC: 0.7261
#
# Epoch 205/999
# ----------
# train Loss: 0.2008, ROC: 0.9336, PRC: 0.7555
# val Loss: 0.2495, ROC: 0.9242, PRC: 0.7319
#
# Epoch 206/999
# ----------
# train Loss: 0.2012, ROC: 0.9332, PRC: 0.7561
# val Loss: 0.2514, ROC: 0.9248, PRC: 0.7342
#
# Epoch 207/999
# ----------
# train Loss: 0.2012, ROC: 0.9328, PRC: 0.7556
# val Loss: 0.2510, ROC: 0.9241, PRC: 0.7310
#
# Epoch 208/999
# ----------
# train Loss: 0.2006, ROC: 0.9339, PRC: 0.7551
# val Loss: 0.2489, ROC: 0.9249, PRC: 0.7336
#
# Epoch 209/999
# ----------
# train Loss: 0.1991, ROC: 0.9345, PRC: 0.7596
# val Loss: 0.2467, ROC: 0.9244, PRC: 0.7317
#
# Epoch 210/999
# ----------
# train Loss: 0.2007, ROC: 0.9334, PRC: 0.7567
# val Loss: 0.2494, ROC: 0.9229, PRC: 0.7260
#
# Epoch 211/999
# ----------
# train Loss: 0.2026, ROC: 0.9327, PRC: 0.7511
# val Loss: 0.2542, ROC: 0.9209, PRC: 0.7196
#
# Epoch 212/999
# ----------
# train Loss: 0.2032, ROC: 0.9318, PRC: 0.7498
# val Loss: 0.2523, ROC: 0.9223, PRC: 0.7235
#
# Epoch 213/999
# ----------
# train Loss: 0.2035, ROC: 0.9317, PRC: 0.7501
# val Loss: 0.2489, ROC: 0.9226, PRC: 0.7234
#
# Epoch 214/999
# ----------
# train Loss: 0.2013, ROC: 0.9330, PRC: 0.7556
# val Loss: 0.2530, ROC: 0.9217, PRC: 0.7232
#
# Epoch 215/999
# ----------
# train Loss: 0.2030, ROC: 0.9315, PRC: 0.7522
# val Loss: 0.2513, ROC: 0.9223, PRC: 0.7245
#
# Epoch 216/999
# ----------
# train Loss: 0.2000, ROC: 0.9347, PRC: 0.7563
# val Loss: 0.2543, ROC: 0.9221, PRC: 0.7234
#
# Epoch 217/999
# ----------
# train Loss: 0.1995, ROC: 0.9342, PRC: 0.7595
# val Loss: 0.2517, ROC: 0.9226, PRC: 0.7272
#
# Epoch 218/999
# ----------
# train Loss: 0.2010, ROC: 0.9336, PRC: 0.7552
# val Loss: 0.2511, ROC: 0.9222, PRC: 0.7263
#
# Epoch 219/999
# ----------
# train Loss: 0.1990, ROC: 0.9352, PRC: 0.7598
# val Loss: 0.2477, ROC: 0.9245, PRC: 0.7324
#
# Epoch 220/999
# ----------
# train Loss: 0.2003, ROC: 0.9338, PRC: 0.7582
# val Loss: 0.2487, ROC: 0.9220, PRC: 0.7245
#
# Epoch 221/999
# ----------
# train Loss: 0.2020, ROC: 0.9322, PRC: 0.7551
# val Loss: 0.2514, ROC: 0.9228, PRC: 0.7260
#
# Epoch 222/999
# ----------
# train Loss: 0.2012, ROC: 0.9327, PRC: 0.7569
# val Loss: 0.2468, ROC: 0.9248, PRC: 0.7334
#
# Epoch 223/999
# ----------
# train Loss: 0.1986, ROC: 0.9353, PRC: 0.7601
# val Loss: 0.2497, ROC: 0.9227, PRC: 0.7275
#
# Epoch 224/999
# ----------
# train Loss: 0.2026, ROC: 0.9324, PRC: 0.7522
# val Loss: 0.2500, ROC: 0.9239, PRC: 0.7309
#
# Epoch 225/999
# ----------
# train Loss: 0.2009, ROC: 0.9339, PRC: 0.7559
# val Loss: 0.2462, ROC: 0.9256, PRC: 0.7355
#
# Epoch 226/999
# ----------
# train Loss: 0.1994, ROC: 0.9344, PRC: 0.7595
# val Loss: 0.2465, ROC: 0.9232, PRC: 0.7284
#
# Epoch 227/999
# ----------
# train Loss: 0.2016, ROC: 0.9332, PRC: 0.7536
# val Loss: 0.2498, ROC: 0.9246, PRC: 0.7339
#
# Epoch 228/999
# ----------
# train Loss: 0.2006, ROC: 0.9336, PRC: 0.7575
# val Loss: 0.2516, ROC: 0.9244, PRC: 0.7316
#
# Epoch 229/999
# ----------
# train Loss: 0.1996, ROC: 0.9348, PRC: 0.7580
# val Loss: 0.2475, ROC: 0.9245, PRC: 0.7346
#
# Epoch 230/999
# ----------
# train Loss: 0.1993, ROC: 0.9346, PRC: 0.7585
# val Loss: 0.2471, ROC: 0.9233, PRC: 0.7286
#
# Epoch 231/999
# ----------
# train Loss: 0.1997, ROC: 0.9347, PRC: 0.7569
# val Loss: 0.2482, ROC: 0.9245, PRC: 0.7331
#
# Epoch 232/999
# ----------
# train Loss: 0.2002, ROC: 0.9342, PRC: 0.7576
# val Loss: 0.2480, ROC: 0.9230, PRC: 0.7289
#
# Epoch 233/999
# ----------
# train Loss: 0.2003, ROC: 0.9344, PRC: 0.7577
# val Loss: 0.2451, ROC: 0.9236, PRC: 0.7310
#
# Epoch 234/999
# ----------
# train Loss: 0.1976, ROC: 0.9358, PRC: 0.7657
# val Loss: 0.2483, ROC: 0.9240, PRC: 0.7320
#
# Epoch 235/999
# ----------
# train Loss: 0.2003, ROC: 0.9338, PRC: 0.7573
# val Loss: 0.2451, ROC: 0.9238, PRC: 0.7307
#
# Epoch 236/999
# ----------
# train Loss: 0.1998, ROC: 0.9338, PRC: 0.7568
# val Loss: 0.2502, ROC: 0.9228, PRC: 0.7290
#
# Epoch 237/999
# ----------
# train Loss: 0.1985, ROC: 0.9350, PRC: 0.7607
# val Loss: 0.2503, ROC: 0.9239, PRC: 0.7300
#
# Epoch 238/999
# ----------
# train Loss: 0.1991, ROC: 0.9349, PRC: 0.7595
# val Loss: 0.2530, ROC: 0.9215, PRC: 0.7218
#
# Epoch 239/999
# ----------
# train Loss: 0.2001, ROC: 0.9342, PRC: 0.7587
# val Loss: 0.2480, ROC: 0.9248, PRC: 0.7338
#
# Epoch 240/999
# ----------
# train Loss: 0.2013, ROC: 0.9329, PRC: 0.7549
# val Loss: 0.2511, ROC: 0.9245, PRC: 0.7330
#
# Epoch 241/999
# ----------
# train Loss: 0.1981, ROC: 0.9356, PRC: 0.7622
# val Loss: 0.2538, ROC: 0.9234, PRC: 0.7305
#
# Epoch 242/999
# ----------
# train Loss: 0.1992, ROC: 0.9351, PRC: 0.7584
# val Loss: 0.2475, ROC: 0.9231, PRC: 0.7289
#
# Epoch 243/999
# ----------
# train Loss: 0.2003, ROC: 0.9337, PRC: 0.7578
# val Loss: 0.2473, ROC: 0.9254, PRC: 0.7346
#
# Epoch 244/999
# ----------
# train Loss: 0.2013, ROC: 0.9337, PRC: 0.7521
# val Loss: 0.2462, ROC: 0.9232, PRC: 0.7270
#
# Epoch 245/999
# ----------
# train Loss: 0.2003, ROC: 0.9338, PRC: 0.7557
# val Loss: 0.2519, ROC: 0.9225, PRC: 0.7266
#
# Epoch 246/999
# ----------
# train Loss: 0.1993, ROC: 0.9346, PRC: 0.7608
# val Loss: 0.2480, ROC: 0.9233, PRC: 0.7287
#
# Epoch 247/999
# ----------
# train Loss: 0.1985, ROC: 0.9351, PRC: 0.7619
# val Loss: 0.2471, ROC: 0.9236, PRC: 0.7288
#
# Epoch 248/999
# ----------
# train Loss: 0.1990, ROC: 0.9350, PRC: 0.7590
# val Loss: 0.2469, ROC: 0.9242, PRC: 0.7309
#
# Epoch 249/999
# ----------
# train Loss: 0.1993, ROC: 0.9345, PRC: 0.7591
# val Loss: 0.2469, ROC: 0.9226, PRC: 0.7260
#
# Epoch 250/999
# ----------
# train Loss: 0.1993, ROC: 0.9346, PRC: 0.7606
# val Loss: 0.2497, ROC: 0.9239, PRC: 0.7287
#
# Epoch 251/999
# ----------
# train Loss: 0.1984, ROC: 0.9349, PRC: 0.7624
# val Loss: 0.2470, ROC: 0.9231, PRC: 0.7279
#
# Epoch 252/999
# ----------
# train Loss: 0.1957, ROC: 0.9372, PRC: 0.7680
# val Loss: 0.2457, ROC: 0.9236, PRC: 0.7261
#
# Epoch 253/999
# ----------
# train Loss: 0.1991, ROC: 0.9351, PRC: 0.7588
# val Loss: 0.2510, ROC: 0.9225, PRC: 0.7237
#
# Epoch 254/999
# ----------
# train Loss: 0.2029, ROC: 0.9325, PRC: 0.7511
# val Loss: 0.2492, ROC: 0.9232, PRC: 0.7245
#
# Epoch 255/999
# ----------
# train Loss: 0.1998, ROC: 0.9340, PRC: 0.7583
# val Loss: 0.2488, ROC: 0.9241, PRC: 0.7274
#
# Epoch 256/999
# ----------
# train Loss: 0.2006, ROC: 0.9338, PRC: 0.7565
# val Loss: 0.2473, ROC: 0.9254, PRC: 0.7321
#
# Epoch 257/999
# ----------
# train Loss: 0.2003, ROC: 0.9341, PRC: 0.7563
# val Loss: 0.2544, ROC: 0.9225, PRC: 0.7228
#
# Epoch 258/999
# ----------
# train Loss: 0.1980, ROC: 0.9356, PRC: 0.7616
# val Loss: 0.2465, ROC: 0.9259, PRC: 0.7349
#
# Epoch 259/999
# ----------
# train Loss: 0.1974, ROC: 0.9361, PRC: 0.7625
# val Loss: 0.2507, ROC: 0.9230, PRC: 0.7248
#
# Epoch 260/999
# ----------
# train Loss: 0.1990, ROC: 0.9346, PRC: 0.7615
# val Loss: 0.2503, ROC: 0.9221, PRC: 0.7226
#
# Epoch 261/999
# ----------
# train Loss: 0.1993, ROC: 0.9345, PRC: 0.7599
# val Loss: 0.2462, ROC: 0.9219, PRC: 0.7217
#
# Epoch 262/999
# ----------
# train Loss: 0.1997, ROC: 0.9346, PRC: 0.7582
# val Loss: 0.2470, ROC: 0.9246, PRC: 0.7312
#
# Epoch 263/999
# ----------
# train Loss: 0.1990, ROC: 0.9350, PRC: 0.7590
# val Loss: 0.2447, ROC: 0.9245, PRC: 0.7290
#
# Epoch 264/999
# ----------
# train Loss: 0.1982, ROC: 0.9355, PRC: 0.7623
# val Loss: 0.2479, ROC: 0.9257, PRC: 0.7339
#
# Epoch 265/999
# ----------
# train Loss: 0.1991, ROC: 0.9352, PRC: 0.7599
# val Loss: 0.2481, ROC: 0.9244, PRC: 0.7304
#
# Epoch 266/999
# ----------
# train Loss: 0.1986, ROC: 0.9352, PRC: 0.7605
# val Loss: 0.2472, ROC: 0.9259, PRC: 0.7352
#
# Epoch 267/999
# ----------
# train Loss: 0.1982, ROC: 0.9353, PRC: 0.7615
# val Loss: 0.2476, ROC: 0.9255, PRC: 0.7338
#
# Epoch 268/999
# ----------
# train Loss: 0.2012, ROC: 0.9331, PRC: 0.7577
# val Loss: 0.2439, ROC: 0.9250, PRC: 0.7328
#
# Epoch 269/999
# ----------
# train Loss: 0.2011, ROC: 0.9335, PRC: 0.7546
# val Loss: 0.2488, ROC: 0.9249, PRC: 0.7321
#
# Epoch 270/999
# ----------
# train Loss: 0.1969, ROC: 0.9363, PRC: 0.7644
# val Loss: 0.2457, ROC: 0.9236, PRC: 0.7289
#
# Epoch 271/999
# ----------
# train Loss: 0.2004, ROC: 0.9341, PRC: 0.7575
# val Loss: 0.2504, ROC: 0.9207, PRC: 0.7199
#
# Epoch 272/999
# ----------
# train Loss: 0.1980, ROC: 0.9356, PRC: 0.7624
# val Loss: 0.2484, ROC: 0.9221, PRC: 0.7244
#
# Epoch 273/999
# ----------
# train Loss: 0.2010, ROC: 0.9337, PRC: 0.7562
# val Loss: 0.2511, ROC: 0.9249, PRC: 0.7326
#
# Epoch 274/999
# ----------
# train Loss: 0.1995, ROC: 0.9348, PRC: 0.7574
# val Loss: 0.2448, ROC: 0.9247, PRC: 0.7324
#
# Epoch 275/999
# ----------
# train Loss: 0.1998, ROC: 0.9339, PRC: 0.7577
# val Loss: 0.2451, ROC: 0.9240, PRC: 0.7298
#
# Epoch 276/999
# ----------
# train Loss: 0.1989, ROC: 0.9356, PRC: 0.7577
# val Loss: 0.2460, ROC: 0.9229, PRC: 0.7260
#
# Epoch 277/999
# ----------
# train Loss: 0.2008, ROC: 0.9335, PRC: 0.7569
# val Loss: 0.2500, ROC: 0.9219, PRC: 0.7234
#
# Epoch 278/999
# ----------
# train Loss: 0.1998, ROC: 0.9344, PRC: 0.7594
# val Loss: 0.2481, ROC: 0.9227, PRC: 0.7261
#
# Epoch 279/999
# ----------
# train Loss: 0.1989, ROC: 0.9353, PRC: 0.7602
# val Loss: 0.2487, ROC: 0.9222, PRC: 0.7243
#
# Epoch 280/999
# ----------
# train Loss: 0.1984, ROC: 0.9357, PRC: 0.7588
# val Loss: 0.2473, ROC: 0.9226, PRC: 0.7259
#
# Epoch 281/999
# ----------
# train Loss: 0.1999, ROC: 0.9345, PRC: 0.7581
# val Loss: 0.2520, ROC: 0.9227, PRC: 0.7245
#
# Epoch 282/999
# ----------
# train Loss: 0.2006, ROC: 0.9339, PRC: 0.7565
# val Loss: 0.2454, ROC: 0.9236, PRC: 0.7286
#
# Epoch 283/999
# ----------
# train Loss: 0.1995, ROC: 0.9345, PRC: 0.7579
# val Loss: 0.2500, ROC: 0.9216, PRC: 0.7224
#
# Epoch 284/999
# ----------
# train Loss: 0.1986, ROC: 0.9350, PRC: 0.7622
# val Loss: 0.2473, ROC: 0.9246, PRC: 0.7306
#
# Epoch 285/999
# ----------
# train Loss: 0.1974, ROC: 0.9358, PRC: 0.7629
# val Loss: 0.2506, ROC: 0.9231, PRC: 0.7258
#
# Epoch 286/999
# ----------
# train Loss: 0.1999, ROC: 0.9340, PRC: 0.7597
# val Loss: 0.2499, ROC: 0.9219, PRC: 0.7223
#
# Epoch 287/999
# ----------
# train Loss: 0.1982, ROC: 0.9357, PRC: 0.7629
# val Loss: 0.2446, ROC: 0.9238, PRC: 0.7274
#
# Epoch 288/999
# ----------
# train Loss: 0.1965, ROC: 0.9364, PRC: 0.7659
# val Loss: 0.2509, ROC: 0.9218, PRC: 0.7215
#
# Epoch 289/999
# ----------
# train Loss: 0.2013, ROC: 0.9333, PRC: 0.7552
# val Loss: 0.2517, ROC: 0.9238, PRC: 0.7274
#
# Epoch 290/999
# ----------
# train Loss: 0.2006, ROC: 0.9335, PRC: 0.7577
# val Loss: 0.2517, ROC: 0.9220, PRC: 0.7220
#
# Epoch 291/999
# ----------
# train Loss: 0.1976, ROC: 0.9354, PRC: 0.7634
# val Loss: 0.2513, ROC: 0.9227, PRC: 0.7251
#
# Epoch 292/999
# ----------
# train Loss: 0.1976, ROC: 0.9361, PRC: 0.7622
# val Loss: 0.2510, ROC: 0.9219, PRC: 0.7229
#
# Epoch 293/999
# ----------
# train Loss: 0.1994, ROC: 0.9349, PRC: 0.7597
# val Loss: 0.2498, ROC: 0.9229, PRC: 0.7256
#
# Epoch 294/999
# ----------
# train Loss: 0.1994, ROC: 0.9345, PRC: 0.7585
# val Loss: 0.2482, ROC: 0.9243, PRC: 0.7313
#
# Epoch 295/999
# ----------
# train Loss: 0.1998, ROC: 0.9343, PRC: 0.7591
# val Loss: 0.2502, ROC: 0.9231, PRC: 0.7270
#
# Epoch 296/999
# ----------
# train Loss: 0.1980, ROC: 0.9355, PRC: 0.7617
# val Loss: 0.2452, ROC: 0.9237, PRC: 0.7306
#
# Epoch 297/999
# ----------
# train Loss: 0.2018, ROC: 0.9330, PRC: 0.7519
# val Loss: 0.2510, ROC: 0.9234, PRC: 0.7272
#
# Epoch 298/999
# ----------
# train Loss: 0.1960, ROC: 0.9372, PRC: 0.7668
# val Loss: 0.2472, ROC: 0.9239, PRC: 0.7310
#
# Epoch 299/999
# ----------
# train Loss: 0.1974, ROC: 0.9361, PRC: 0.7619
# val Loss: 0.2434, ROC: 0.9249, PRC: 0.7345
#
# Epoch 300/999
# ----------
# train Loss: 0.1978, ROC: 0.9355, PRC: 0.7641
# val Loss: 0.2496, ROC: 0.9237, PRC: 0.7298
#
# Epoch 301/999
# ----------
# train Loss: 0.1992, ROC: 0.9353, PRC: 0.7579
# val Loss: 0.2441, ROC: 0.9242, PRC: 0.7312
#
# Epoch 302/999
# ----------
# train Loss: 0.1997, ROC: 0.9345, PRC: 0.7605
# val Loss: 0.2488, ROC: 0.9225, PRC: 0.7246
#
# Epoch 303/999
# ----------
# train Loss: 0.1977, ROC: 0.9357, PRC: 0.7643
# val Loss: 0.2478, ROC: 0.9222, PRC: 0.7255
#
# Epoch 304/999
# ----------
# train Loss: 0.1970, ROC: 0.9361, PRC: 0.7653
# val Loss: 0.2434, ROC: 0.9246, PRC: 0.7347
#
# Epoch 305/999
# ----------
# train Loss: 0.1976, ROC: 0.9359, PRC: 0.7635
# val Loss: 0.2467, ROC: 0.9236, PRC: 0.7304
#
# Epoch 306/999
# ----------
# train Loss: 0.1991, ROC: 0.9348, PRC: 0.7602
# val Loss: 0.2464, ROC: 0.9252, PRC: 0.7346
#
# Epoch 307/999
# ----------
# train Loss: 0.1958, ROC: 0.9369, PRC: 0.7679
# val Loss: 0.2469, ROC: 0.9235, PRC: 0.7298
#
# Epoch 308/999
# ----------
# train Loss: 0.1983, ROC: 0.9352, PRC: 0.7611
# val Loss: 0.2433, ROC: 0.9266, PRC: 0.7386
#
# Epoch 309/999
# ----------
# train Loss: 0.1983, ROC: 0.9356, PRC: 0.7601
# val Loss: 0.2468, ROC: 0.9263, PRC: 0.7384
#
# Epoch 310/999
# ----------
# train Loss: 0.1982, ROC: 0.9356, PRC: 0.7619
# val Loss: 0.2446, ROC: 0.9266, PRC: 0.7392
#
# Epoch 311/999
# ----------
# train Loss: 0.1970, ROC: 0.9359, PRC: 0.7667
# val Loss: 0.2425, ROC: 0.9276, PRC: 0.7424
#
# Epoch 312/999
# ----------
# train Loss: 0.1987, ROC: 0.9354, PRC: 0.7607
# val Loss: 0.2504, ROC: 0.9275, PRC: 0.7420
#
# Epoch 313/999
# ----------
# train Loss: 0.1960, ROC: 0.9368, PRC: 0.7664
# val Loss: 0.2430, ROC: 0.9274, PRC: 0.7406
#
# Epoch 314/999
# ----------
# train Loss: 0.1995, ROC: 0.9345, PRC: 0.7593
# val Loss: 0.2458, ROC: 0.9276, PRC: 0.7418
#
# Epoch 315/999
# ----------
# train Loss: 0.1987, ROC: 0.9356, PRC: 0.7602
# val Loss: 0.2438, ROC: 0.9244, PRC: 0.7311
#
# Epoch 316/999
# ----------
# train Loss: 0.2005, ROC: 0.9339, PRC: 0.7576
# val Loss: 0.2475, ROC: 0.9236, PRC: 0.7273
#
# Epoch 317/999
# ----------
# train Loss: 0.1978, ROC: 0.9355, PRC: 0.7630
# val Loss: 0.2474, ROC: 0.9258, PRC: 0.7362
#
# Epoch 318/999
# ----------
# train Loss: 0.1966, ROC: 0.9368, PRC: 0.7642
# val Loss: 0.2435, ROC: 0.9269, PRC: 0.7389
#
# Epoch 319/999
# ----------
# train Loss: 0.1996, ROC: 0.9348, PRC: 0.7588
# val Loss: 0.2462, ROC: 0.9253, PRC: 0.7347
#
# Epoch 320/999
# ----------
# train Loss: 0.1971, ROC: 0.9364, PRC: 0.7653
# val Loss: 0.2422, ROC: 0.9282, PRC: 0.7448
#
# Epoch 321/999
# ----------
# train Loss: 0.1994, ROC: 0.9346, PRC: 0.7590
# val Loss: 0.2420, ROC: 0.9277, PRC: 0.7429
#
# Epoch 322/999
# ----------
# train Loss: 0.1996, ROC: 0.9345, PRC: 0.7579
# val Loss: 0.2431, ROC: 0.9267, PRC: 0.7395
#
# Epoch 323/999
# ----------
# train Loss: 0.1989, ROC: 0.9353, PRC: 0.7596
# val Loss: 0.2462, ROC: 0.9260, PRC: 0.7365
#
# Epoch 324/999
# ----------
# train Loss: 0.1984, ROC: 0.9355, PRC: 0.7630
# val Loss: 0.2420, ROC: 0.9266, PRC: 0.7393
#
# Epoch 325/999
# ----------
# train Loss: 0.1971, ROC: 0.9364, PRC: 0.7636
# val Loss: 0.2428, ROC: 0.9276, PRC: 0.7424
#
# Epoch 326/999
# ----------
# train Loss: 0.1954, ROC: 0.9380, PRC: 0.7673
# val Loss: 0.2415, ROC: 0.9283, PRC: 0.7454
#
# Epoch 327/999
# ----------
# train Loss: 0.1983, ROC: 0.9358, PRC: 0.7603
# val Loss: 0.2398, ROC: 0.9274, PRC: 0.7407
#
# Epoch 328/999
# ----------
# train Loss: 0.1984, ROC: 0.9353, PRC: 0.7604
# val Loss: 0.2487, ROC: 0.9264, PRC: 0.7362
#
# Epoch 329/999
# ----------
# train Loss: 0.1976, ROC: 0.9363, PRC: 0.7619
# val Loss: 0.2491, ROC: 0.9265, PRC: 0.7373
#
# Epoch 330/999
# ----------
# train Loss: 0.1994, ROC: 0.9346, PRC: 0.7581
# val Loss: 0.2450, ROC: 0.9283, PRC: 0.7452
#
# Epoch 331/999
# ----------
# train Loss: 0.1962, ROC: 0.9370, PRC: 0.7665
# val Loss: 0.2456, ROC: 0.9265, PRC: 0.7390
#
# Epoch 332/999
# ----------
# train Loss: 0.1976, ROC: 0.9365, PRC: 0.7622
# val Loss: 0.2447, ROC: 0.9260, PRC: 0.7372
#
# Epoch 333/999
# ----------
# train Loss: 0.2003, ROC: 0.9337, PRC: 0.7572
# val Loss: 0.2411, ROC: 0.9279, PRC: 0.7435
#
# Epoch 334/999
# ----------
# train Loss: 0.1984, ROC: 0.9354, PRC: 0.7602
# val Loss: 0.2425, ROC: 0.9271, PRC: 0.7407
#
# Epoch 335/999
# ----------
# train Loss: 0.1973, ROC: 0.9367, PRC: 0.7634
# val Loss: 0.2376, ROC: 0.9288, PRC: 0.7474
#
# Epoch 336/999
# ----------
# train Loss: 0.1971, ROC: 0.9366, PRC: 0.7658
# val Loss: 0.2442, ROC: 0.9273, PRC: 0.7423
#
# Epoch 337/999
# ----------
# train Loss: 0.1969, ROC: 0.9366, PRC: 0.7649
# val Loss: 0.2442, ROC: 0.9276, PRC: 0.7407
#
# Epoch 338/999
# ----------
# train Loss: 0.1989, ROC: 0.9356, PRC: 0.7572
# val Loss: 0.2454, ROC: 0.9265, PRC: 0.7377
#
# Epoch 339/999
# ----------
# train Loss: 0.1970, ROC: 0.9364, PRC: 0.7633
# val Loss: 0.2444, ROC: 0.9251, PRC: 0.7338
#
# Epoch 340/999
# ----------
# train Loss: 0.1976, ROC: 0.9363, PRC: 0.7615
# val Loss: 0.2501, ROC: 0.9258, PRC: 0.7360
#
# Epoch 341/999
# ----------
# train Loss: 0.1980, ROC: 0.9355, PRC: 0.7621
# val Loss: 0.2433, ROC: 0.9261, PRC: 0.7366
#
# Epoch 342/999
# ----------
# train Loss: 0.1972, ROC: 0.9365, PRC: 0.7652
# val Loss: 0.2475, ROC: 0.9248, PRC: 0.7313
#
# Epoch 343/999
# ----------
# train Loss: 0.1973, ROC: 0.9358, PRC: 0.7648
# val Loss: 0.2423, ROC: 0.9266, PRC: 0.7393
#
# Epoch 344/999
# ----------
# train Loss: 0.1957, ROC: 0.9371, PRC: 0.7672
# val Loss: 0.2426, ROC: 0.9252, PRC: 0.7350
#
# Epoch 345/999
# ----------
# train Loss: 0.1970, ROC: 0.9364, PRC: 0.7645
# val Loss: 0.2423, ROC: 0.9253, PRC: 0.7367
#
# Epoch 346/999
# ----------
# train Loss: 0.1968, ROC: 0.9369, PRC: 0.7632
# val Loss: 0.2423, ROC: 0.9273, PRC: 0.7441
#
# Epoch 347/999
# ----------
# train Loss: 0.1985, ROC: 0.9349, PRC: 0.7621
# val Loss: 0.2388, ROC: 0.9278, PRC: 0.7467
#
# Epoch 348/999
# ----------
# train Loss: 0.1962, ROC: 0.9364, PRC: 0.7693
# val Loss: 0.2416, ROC: 0.9264, PRC: 0.7415
#
# Epoch 349/999
# ----------
# train Loss: 0.1929, ROC: 0.9390, PRC: 0.7738
# val Loss: 0.2453, ROC: 0.9265, PRC: 0.7402
#
# Epoch 350/999
# ----------
# train Loss: 0.1980, ROC: 0.9359, PRC: 0.7620
# val Loss: 0.2469, ROC: 0.9267, PRC: 0.7408
#
# Epoch 351/999
# ----------
# train Loss: 0.1969, ROC: 0.9364, PRC: 0.7644
# val Loss: 0.2493, ROC: 0.9264, PRC: 0.7388
#
# Epoch 352/999
# ----------
# train Loss: 0.1962, ROC: 0.9367, PRC: 0.7659
# val Loss: 0.2399, ROC: 0.9275, PRC: 0.7438
#
# Epoch 353/999
# ----------
# train Loss: 0.1968, ROC: 0.9370, PRC: 0.7640
# val Loss: 0.2418, ROC: 0.9278, PRC: 0.7447
#
# Epoch 354/999
# ----------
# train Loss: 0.1966, ROC: 0.9362, PRC: 0.7662
# val Loss: 0.2427, ROC: 0.9271, PRC: 0.7410
#
# Epoch 355/999
# ----------
# train Loss: 0.1976, ROC: 0.9356, PRC: 0.7644
# val Loss: 0.2466, ROC: 0.9268, PRC: 0.7401
#
# Epoch 356/999
# ----------
# train Loss: 0.1958, ROC: 0.9375, PRC: 0.7666
# val Loss: 0.2410, ROC: 0.9252, PRC: 0.7360
#
# Epoch 357/999
# ----------
# train Loss: 0.1954, ROC: 0.9376, PRC: 0.7686
# val Loss: 0.2438, ROC: 0.9259, PRC: 0.7374
#
# Epoch 358/999
# ----------
# train Loss: 0.1962, ROC: 0.9368, PRC: 0.7662
# val Loss: 0.2448, ROC: 0.9254, PRC: 0.7360
#
# Epoch 359/999
# ----------
# train Loss: 0.1967, ROC: 0.9362, PRC: 0.7676
# val Loss: 0.2408, ROC: 0.9258, PRC: 0.7368
#
# Epoch 360/999
# ----------
# train Loss: 0.1987, ROC: 0.9350, PRC: 0.7616
# val Loss: 0.2434, ROC: 0.9263, PRC: 0.7374
#
# Epoch 361/999
# ----------
# train Loss: 0.1978, ROC: 0.9361, PRC: 0.7626
# val Loss: 0.2481, ROC: 0.9257, PRC: 0.7358
#
# Epoch 362/999
# ----------
# train Loss: 0.1970, ROC: 0.9362, PRC: 0.7652
# val Loss: 0.2463, ROC: 0.9243, PRC: 0.7310
#
# Epoch 363/999
# ----------
# train Loss: 0.1961, ROC: 0.9375, PRC: 0.7653
# val Loss: 0.2463, ROC: 0.9253, PRC: 0.7365
#
# Epoch 364/999
# ----------
# train Loss: 0.1971, ROC: 0.9363, PRC: 0.7642
# val Loss: 0.2442, ROC: 0.9248, PRC: 0.7334
#
# Epoch 365/999
# ----------
# train Loss: 0.1962, ROC: 0.9375, PRC: 0.7642
# val Loss: 0.2397, ROC: 0.9262, PRC: 0.7394
#
# Epoch 366/999
# ----------
# train Loss: 0.1970, ROC: 0.9362, PRC: 0.7649
# val Loss: 0.2387, ROC: 0.9269, PRC: 0.7412
#
# Epoch 367/999
# ----------
# train Loss: 0.1972, ROC: 0.9361, PRC: 0.7658
# val Loss: 0.2441, ROC: 0.9258, PRC: 0.7354
#
# Epoch 368/999
# ----------
# train Loss: 0.1983, ROC: 0.9355, PRC: 0.7622
# val Loss: 0.2457, ROC: 0.9251, PRC: 0.7355
#
# Epoch 369/999
# ----------
# train Loss: 0.1950, ROC: 0.9383, PRC: 0.7693
# val Loss: 0.2470, ROC: 0.9277, PRC: 0.7427
#
# Epoch 370/999
# ----------
# train Loss: 0.1995, ROC: 0.9349, PRC: 0.7579
# val Loss: 0.2431, ROC: 0.9276, PRC: 0.7441
#
# Epoch 371/999
# ----------
# train Loss: 0.1957, ROC: 0.9378, PRC: 0.7656
# val Loss: 0.2433, ROC: 0.9264, PRC: 0.7387
#
# Epoch 372/999
# ----------
# train Loss: 0.1969, ROC: 0.9367, PRC: 0.7647
# val Loss: 0.2428, ROC: 0.9271, PRC: 0.7420
#
# Epoch 373/999
# ----------
# train Loss: 0.1978, ROC: 0.9359, PRC: 0.7656
# val Loss: 0.2468, ROC: 0.9263, PRC: 0.7381
#
# Epoch 374/999
# ----------
# train Loss: 0.1980, ROC: 0.9359, PRC: 0.7616
# val Loss: 0.2506, ROC: 0.9254, PRC: 0.7365
#
# Epoch 375/999
# ----------
# train Loss: 0.1963, ROC: 0.9369, PRC: 0.7665
# val Loss: 0.2469, ROC: 0.9261, PRC: 0.7383
#
# Epoch 376/999
# ----------
# train Loss: 0.1976, ROC: 0.9357, PRC: 0.7638
# val Loss: 0.2512, ROC: 0.9251, PRC: 0.7353
#
# Epoch 377/999
# ----------
# train Loss: 0.1964, ROC: 0.9365, PRC: 0.7679
# val Loss: 0.2435, ROC: 0.9284, PRC: 0.7456
#
# Epoch 378/999
# ----------
# train Loss: 0.1965, ROC: 0.9366, PRC: 0.7650
# val Loss: 0.2483, ROC: 0.9263, PRC: 0.7397
#
# Epoch 379/999
# ----------
# train Loss: 0.1971, ROC: 0.9365, PRC: 0.7642
# val Loss: 0.2441, ROC: 0.9262, PRC: 0.7394
#
# Epoch 380/999
# ----------
# train Loss: 0.1966, ROC: 0.9373, PRC: 0.7659
# val Loss: 0.2458, ROC: 0.9261, PRC: 0.7387
#
# Epoch 381/999
# ----------
# train Loss: 0.1957, ROC: 0.9368, PRC: 0.7675
# val Loss: 0.2461, ROC: 0.9250, PRC: 0.7371
#
# Epoch 382/999
# ----------
# train Loss: 0.1967, ROC: 0.9365, PRC: 0.7647
# val Loss: 0.2506, ROC: 0.9257, PRC: 0.7392
#
# Epoch 383/999
# ----------
# train Loss: 0.1968, ROC: 0.9367, PRC: 0.7635
# val Loss: 0.2450, ROC: 0.9247, PRC: 0.7356
#
# Epoch 384/999
# ----------
# train Loss: 0.1942, ROC: 0.9390, PRC: 0.7687
# val Loss: 0.2407, ROC: 0.9254, PRC: 0.7377
#
# Epoch 385/999
# ----------
# train Loss: 0.1962, ROC: 0.9369, PRC: 0.7650
# val Loss: 0.2430, ROC: 0.9277, PRC: 0.7458
#
# Epoch 386/999
# ----------
# train Loss: 0.1977, ROC: 0.9363, PRC: 0.7633
# val Loss: 0.2417, ROC: 0.9260, PRC: 0.7400
#
# Epoch 387/999
# ----------
# train Loss: 0.1992, ROC: 0.9347, PRC: 0.7603
# val Loss: 0.2434, ROC: 0.9256, PRC: 0.7389
#
# Epoch 388/999
# ----------
# train Loss: 0.1972, ROC: 0.9368, PRC: 0.7623
# val Loss: 0.2448, ROC: 0.9266, PRC: 0.7406
#
# Epoch 389/999
# ----------
# train Loss: 0.1981, ROC: 0.9356, PRC: 0.7620
# val Loss: 0.2439, ROC: 0.9266, PRC: 0.7407
#
# Epoch 390/999
# ----------
# train Loss: 0.1948, ROC: 0.9383, PRC: 0.7705
# val Loss: 0.2424, ROC: 0.9267, PRC: 0.7418
#
# Epoch 391/999
# ----------
# train Loss: 0.1961, ROC: 0.9372, PRC: 0.7663
# val Loss: 0.2383, ROC: 0.9266, PRC: 0.7395
#
# Epoch 392/999
# ----------
# train Loss: 0.1971, ROC: 0.9358, PRC: 0.7652
# val Loss: 0.2388, ROC: 0.9278, PRC: 0.7442
#
# Epoch 393/999
# ----------
# train Loss: 0.1962, ROC: 0.9371, PRC: 0.7675
# val Loss: 0.2381, ROC: 0.9275, PRC: 0.7442
#
# Epoch 394/999
# ----------
# train Loss: 0.1955, ROC: 0.9376, PRC: 0.7678
# val Loss: 0.2435, ROC: 0.9261, PRC: 0.7383
#
# Epoch 395/999
# ----------
# train Loss: 0.1950, ROC: 0.9380, PRC: 0.7679
# val Loss: 0.2387, ROC: 0.9269, PRC: 0.7410
#
# Epoch 396/999
# ----------
# train Loss: 0.1941, ROC: 0.9389, PRC: 0.7690
# val Loss: 0.2397, ROC: 0.9279, PRC: 0.7441
#
# Epoch 397/999
# ----------
# train Loss: 0.1959, ROC: 0.9370, PRC: 0.7696
# val Loss: 0.2420, ROC: 0.9279, PRC: 0.7461
#
# Epoch 398/999
# ----------
# train Loss: 0.1944, ROC: 0.9380, PRC: 0.7714
# val Loss: 0.2434, ROC: 0.9276, PRC: 0.7452
#
# Epoch 399/999
# ----------
# train Loss: 0.1968, ROC: 0.9368, PRC: 0.7659
# val Loss: 0.2402, ROC: 0.9272, PRC: 0.7432
#
# Epoch 400/999
# ----------
# train Loss: 0.1982, ROC: 0.9358, PRC: 0.7608
# val Loss: 0.2455, ROC: 0.9262, PRC: 0.7400
#
# Epoch 401/999
# ----------
# train Loss: 0.1963, ROC: 0.9361, PRC: 0.7678
# val Loss: 0.2430, ROC: 0.9274, PRC: 0.7445
#
# Epoch 402/999
# ----------
# train Loss: 0.1953, ROC: 0.9375, PRC: 0.7684
# val Loss: 0.2416, ROC: 0.9268, PRC: 0.7442
#
# Epoch 403/999
# ----------
# train Loss: 0.1942, ROC: 0.9383, PRC: 0.7700
# val Loss: 0.2375, ROC: 0.9272, PRC: 0.7446
#
# Epoch 404/999
# ----------
# train Loss: 0.1963, ROC: 0.9370, PRC: 0.7653
# val Loss: 0.2415, ROC: 0.9277, PRC: 0.7449
#
# Epoch 405/999
# ----------
# train Loss: 0.1958, ROC: 0.9370, PRC: 0.7670
# val Loss: 0.2374, ROC: 0.9281, PRC: 0.7449
#
# Epoch 406/999
# ----------
# train Loss: 0.1928, ROC: 0.9392, PRC: 0.7740
# val Loss: 0.2340, ROC: 0.9294, PRC: 0.7493
#
# Epoch 407/999
# ----------
# train Loss: 0.1971, ROC: 0.9363, PRC: 0.7645
# val Loss: 0.2408, ROC: 0.9279, PRC: 0.7451
#
# Epoch 408/999
# ----------
# train Loss: 0.1941, ROC: 0.9383, PRC: 0.7705
# val Loss: 0.2372, ROC: 0.9282, PRC: 0.7460
#
# Epoch 409/999
# ----------
# train Loss: 0.1974, ROC: 0.9365, PRC: 0.7636
# val Loss: 0.2352, ROC: 0.9277, PRC: 0.7448
#
# Epoch 410/999
# ----------
# train Loss: 0.1951, ROC: 0.9379, PRC: 0.7693
# val Loss: 0.2392, ROC: 0.9272, PRC: 0.7419
#
# Epoch 411/999
# ----------
# train Loss: 0.1969, ROC: 0.9367, PRC: 0.7657
# val Loss: 0.2424, ROC: 0.9273, PRC: 0.7435
#
# Epoch 412/999
# ----------
# train Loss: 0.1966, ROC: 0.9370, PRC: 0.7630
# val Loss: 0.2418, ROC: 0.9282, PRC: 0.7445
#
# Epoch 413/999
# ----------
# train Loss: 0.1963, ROC: 0.9369, PRC: 0.7649
# val Loss: 0.2407, ROC: 0.9283, PRC: 0.7457
#
# Epoch 414/999
# ----------
# train Loss: 0.1967, ROC: 0.9370, PRC: 0.7638
# val Loss: 0.2431, ROC: 0.9274, PRC: 0.7439
#
# Epoch 415/999
# ----------
# train Loss: 0.1963, ROC: 0.9369, PRC: 0.7670
# val Loss: 0.2380, ROC: 0.9276, PRC: 0.7440
#
# Epoch 416/999
# ----------
# train Loss: 0.1965, ROC: 0.9368, PRC: 0.7659
# val Loss: 0.2412, ROC: 0.9268, PRC: 0.7433
#
# Epoch 417/999
# ----------
# train Loss: 0.1970, ROC: 0.9367, PRC: 0.7632
# val Loss: 0.2387, ROC: 0.9275, PRC: 0.7435
#
# Epoch 418/999
# ----------
# train Loss: 0.1960, ROC: 0.9369, PRC: 0.7672
# val Loss: 0.2391, ROC: 0.9282, PRC: 0.7463
#
# Epoch 419/999
# ----------
# train Loss: 0.1962, ROC: 0.9377, PRC: 0.7663
# val Loss: 0.2375, ROC: 0.9286, PRC: 0.7482
#
# Epoch 420/999
# ----------
# train Loss: 0.1945, ROC: 0.9384, PRC: 0.7705
# val Loss: 0.2403, ROC: 0.9263, PRC: 0.7422
#
# Epoch 421/999
# ----------
# train Loss: 0.1962, ROC: 0.9373, PRC: 0.7651
# val Loss: 0.2445, ROC: 0.9277, PRC: 0.7435
#
# ...
#
# Epoch 862/999
# ----------
# train Loss: 0.1909, ROC: 0.9411, PRC: 0.7787
# val Loss: 0.2469, ROC: 0.9291, PRC: 0.7502
#
# Epoch 863/999
# ----------
# train Loss: 0.1924, ROC: 0.9395, PRC: 0.7759
# val Loss: 0.2535, ROC: 0.9291, PRC: 0.7515
#
# Epoch 864/999
# ----------
# train Loss: 0.1901, ROC: 0.9412, PRC: 0.7793
# val Loss: 0.2505, ROC: 0.9291, PRC: 0.7501
#
# Epoch 865/999
# ----------
# train Loss: 0.1911, ROC: 0.9401, PRC: 0.7771
# val Loss: 0.2588, ROC: 0.9287, PRC: 0.7417
#
# Epoch 866/999
# ----------
# train Loss: 0.1923, ROC: 0.9398, PRC: 0.7749
# val Loss: 0.2502, ROC: 0.9296, PRC: 0.7487
#
# Epoch 867/999
# ----------
# train Loss: 0.1885, ROC: 0.9416, PRC: 0.7845
# val Loss: 0.2556, ROC: 0.9288, PRC: 0.7474
#
# Epoch 868/999
# ----------
# train Loss: 0.1925, ROC: 0.9395, PRC: 0.7738
# val Loss: 0.2515, ROC: 0.9283, PRC: 0.7483
#
# Epoch 869/999
# ----------
# train Loss: 0.1920, ROC: 0.9398, PRC: 0.7765
# val Loss: 0.2587, ROC: 0.9288, PRC: 0.7508
#
# Epoch 870/999
# ----------
# train Loss: 0.1938, ROC: 0.9387, PRC: 0.7727
# val Loss: 0.2562, ROC: 0.9275, PRC: 0.7466
#
# Epoch 871/999
# ----------
# train Loss: 0.1900, ROC: 0.9413, PRC: 0.7796
# val Loss: 0.2516, ROC: 0.9279, PRC: 0.7473
#
# Epoch 872/999
# ----------
# train Loss: 0.1937, ROC: 0.9387, PRC: 0.7725
# val Loss: 0.2622, ROC: 0.9264, PRC: 0.7436
#
# Epoch 873/999
# ----------
# train Loss: 0.1932, ROC: 0.9388, PRC: 0.7730
# val Loss: 0.2591, ROC: 0.9273, PRC: 0.7483
#
# Epoch 874/999
# ----------
# train Loss: 0.1924, ROC: 0.9401, PRC: 0.7750
# val Loss: 0.2529, ROC: 0.9280, PRC: 0.7484
#
# Epoch 875/999
# ----------
# train Loss: 0.1939, ROC: 0.9387, PRC: 0.7700
# val Loss: 0.2533, ROC: 0.9279, PRC: 0.7467
#
# Epoch 876/999
# ----------
# train Loss: 0.1936, ROC: 0.9388, PRC: 0.7744
# val Loss: 0.2556, ROC: 0.9298, PRC: 0.7481
#
# Epoch 877/999
# ----------
# train Loss: 0.1928, ROC: 0.9396, PRC: 0.7743
# val Loss: 0.2498, ROC: 0.9292, PRC: 0.7487
#
# Epoch 878/999
# ----------
# train Loss: 0.1912, ROC: 0.9410, PRC: 0.7765
# val Loss: 0.2526, ROC: 0.9289, PRC: 0.7517
#
# Epoch 879/999
# ----------
# train Loss: 0.1922, ROC: 0.9400, PRC: 0.7739
# val Loss: 0.2523, ROC: 0.9289, PRC: 0.7509
#
# Epoch 880/999
# ----------
# train Loss: 0.1900, ROC: 0.9412, PRC: 0.7793
# val Loss: 0.2462, ROC: 0.9299, PRC: 0.7541
#
# Epoch 881/999
# ----------
# train Loss: 0.1896, ROC: 0.9417, PRC: 0.7807
# val Loss: 0.2494, ROC: 0.9301, PRC: 0.7537
#
# Epoch 882/999
# ----------
# train Loss: 0.1908, ROC: 0.9411, PRC: 0.7764
# val Loss: 0.2490, ROC: 0.9305, PRC: 0.7539
#
# Epoch 883/999
# ----------
# train Loss: 0.1912, ROC: 0.9401, PRC: 0.7774
# val Loss: 0.2515, ROC: 0.9304, PRC: 0.7511
#
# Epoch 884/999
# ----------
# train Loss: 0.1902, ROC: 0.9406, PRC: 0.7810
# val Loss: 0.2582, ROC: 0.9288, PRC: 0.7482
#
# Epoch 885/999
# ----------
# train Loss: 0.1922, ROC: 0.9402, PRC: 0.7740
# val Loss: 0.2555, ROC: 0.9294, PRC: 0.7519
#
# Epoch 886/999
# ----------
# train Loss: 0.1925, ROC: 0.9396, PRC: 0.7733
# val Loss: 0.2572, ROC: 0.9296, PRC: 0.7539
#
# Epoch 887/999
# ----------
# train Loss: 0.1935, ROC: 0.9390, PRC: 0.7713
# val Loss: 0.2523, ROC: 0.9295, PRC: 0.7519
#
# Epoch 888/999
# ----------
# train Loss: 0.1927, ROC: 0.9399, PRC: 0.7738
# val Loss: 0.2501, ROC: 0.9299, PRC: 0.7526
#
# Epoch 889/999
# ----------
# train Loss: 0.1931, ROC: 0.9393, PRC: 0.7724
# val Loss: 0.2484, ROC: 0.9312, PRC: 0.7541
#
# Epoch 890/999
# ----------
# train Loss: 0.1926, ROC: 0.9395, PRC: 0.7754
# val Loss: 0.2542, ROC: 0.9313, PRC: 0.7564
#
# Epoch 891/999
# ----------
# train Loss: 0.1903, ROC: 0.9413, PRC: 0.7781
# val Loss: 0.2480, ROC: 0.9321, PRC: 0.7582
#
# Epoch 892/999
# ----------
# train Loss: 0.1903, ROC: 0.9412, PRC: 0.7778
# val Loss: 0.2467, ROC: 0.9308, PRC: 0.7530
#
# Epoch 893/999
# ----------
# train Loss: 0.1930, ROC: 0.9395, PRC: 0.7716
# val Loss: 0.2482, ROC: 0.9303, PRC: 0.7505
#
# Epoch 894/999
# ----------
# train Loss: 0.1929, ROC: 0.9392, PRC: 0.7746
# val Loss: 0.2529, ROC: 0.9305, PRC: 0.7535
#
# Epoch 895/999
# ----------
# train Loss: 0.1930, ROC: 0.9396, PRC: 0.7717
# val Loss: 0.2453, ROC: 0.9319, PRC: 0.7592
#
# Epoch 896/999
# ----------
# train Loss: 0.1902, ROC: 0.9408, PRC: 0.7790
# val Loss: 0.2525, ROC: 0.9309, PRC: 0.7562
#
# Epoch 897/999
# ----------
# train Loss: 0.1902, ROC: 0.9412, PRC: 0.7783
# val Loss: 0.2453, ROC: 0.9312, PRC: 0.7573
#
# Epoch 898/999
# ----------
# train Loss: 0.1924, ROC: 0.9398, PRC: 0.7747
# val Loss: 0.2539, ROC: 0.9302, PRC: 0.7554
#
# Epoch 899/999
# ----------
# train Loss: 0.1927, ROC: 0.9396, PRC: 0.7735
# val Loss: 0.2447, ROC: 0.9299, PRC: 0.7534
#
# Epoch 900/999
# ----------
# train Loss: 0.1914, ROC: 0.9402, PRC: 0.7761
# val Loss: 0.2569, ROC: 0.9306, PRC: 0.7551
#
# Epoch 901/999
# ----------
# train Loss: 0.1926, ROC: 0.9395, PRC: 0.7740
# val Loss: 0.2492, ROC: 0.9304, PRC: 0.7538
#
# Epoch 902/999
# ----------
# train Loss: 0.1931, ROC: 0.9392, PRC: 0.7734
# val Loss: 0.2544, ROC: 0.9299, PRC: 0.7523
#
# Epoch 903/999
# ----------
# train Loss: 0.1921, ROC: 0.9403, PRC: 0.7759
# val Loss: 0.2497, ROC: 0.9296, PRC: 0.7474
#
# Epoch 904/999
# ----------
# train Loss: 0.1921, ROC: 0.9399, PRC: 0.7765
# val Loss: 0.2541, ROC: 0.9304, PRC: 0.7511
#
# Epoch 905/999
# ----------
# train Loss: 0.1913, ROC: 0.9409, PRC: 0.7754
# val Loss: 0.2568, ROC: 0.9290, PRC: 0.7499
#
# Epoch 906/999
# ----------
# train Loss: 0.1936, ROC: 0.9382, PRC: 0.7716
# val Loss: 0.2502, ROC: 0.9300, PRC: 0.7544
#
# Epoch 907/999
# ----------
# train Loss: 0.1897, ROC: 0.9418, PRC: 0.7817
# val Loss: 0.2529, ROC: 0.9300, PRC: 0.7535
#
# Epoch 908/999
# ----------
# train Loss: 0.1916, ROC: 0.9402, PRC: 0.7786
# val Loss: 0.2499, ROC: 0.9295, PRC: 0.7509
#
# Epoch 909/999
# ----------
# train Loss: 0.1925, ROC: 0.9398, PRC: 0.7729
# val Loss: 0.2540, ROC: 0.9292, PRC: 0.7509
#
# Epoch 910/999
# ----------
# train Loss: 0.1925, ROC: 0.9399, PRC: 0.7743
# val Loss: 0.2524, ROC: 0.9295, PRC: 0.7524
#
# Epoch 911/999
# ----------
# train Loss: 0.1930, ROC: 0.9394, PRC: 0.7735
# val Loss: 0.2567, ROC: 0.9296, PRC: 0.7542
#
# Epoch 912/999
# ----------
# train Loss: 0.1923, ROC: 0.9395, PRC: 0.7763
# val Loss: 0.2490, ROC: 0.9302, PRC: 0.7545
#
# Epoch 913/999
# ----------
# train Loss: 0.1895, ROC: 0.9419, PRC: 0.7799
# val Loss: 0.2566, ROC: 0.9297, PRC: 0.7536
#
# Epoch 914/999
# ----------
# train Loss: 0.1938, ROC: 0.9388, PRC: 0.7704
# val Loss: 0.2576, ROC: 0.9306, PRC: 0.7552
#
# Epoch 915/999
# ----------
# train Loss: 0.1934, ROC: 0.9392, PRC: 0.7719
# val Loss: 0.2551, ROC: 0.9300, PRC: 0.7528
#
# Epoch 916/999
# ----------
# train Loss: 0.1925, ROC: 0.9395, PRC: 0.7745
# val Loss: 0.2598, ROC: 0.9302, PRC: 0.7546
#
# Epoch 917/999
# ----------
# train Loss: 0.1917, ROC: 0.9403, PRC: 0.7769
# val Loss: 0.2620, ROC: 0.9302, PRC: 0.7525
#
# Epoch 918/999
# ----------
# train Loss: 0.1915, ROC: 0.9407, PRC: 0.7756
# val Loss: 0.2534, ROC: 0.9316, PRC: 0.7522
#
# Epoch 919/999
# ----------
# train Loss: 0.1929, ROC: 0.9398, PRC: 0.7736
# val Loss: 0.2538, ROC: 0.9305, PRC: 0.7520
#
# Epoch 920/999
# ----------
# train Loss: 0.1920, ROC: 0.9401, PRC: 0.7745
# val Loss: 0.2665, ROC: 0.9295, PRC: 0.7516
#
# Epoch 921/999
# ----------
# train Loss: 0.1922, ROC: 0.9401, PRC: 0.7751
# val Loss: 0.2557, ROC: 0.9294, PRC: 0.7525
#
# Epoch 922/999
# ----------
# train Loss: 0.1902, ROC: 0.9410, PRC: 0.7796
# val Loss: 0.2578, ROC: 0.9297, PRC: 0.7517
#
# Epoch 923/999
# ----------
# train Loss: 0.1918, ROC: 0.9405, PRC: 0.7749
# val Loss: 0.2511, ROC: 0.9301, PRC: 0.7522
#
# Epoch 924/999
# ----------
# train Loss: 0.1923, ROC: 0.9400, PRC: 0.7745
# val Loss: 0.2495, ROC: 0.9310, PRC: 0.7557
#
# Epoch 925/999
# ----------
# train Loss: 0.1902, ROC: 0.9411, PRC: 0.7785
# val Loss: 0.2583, ROC: 0.9293, PRC: 0.7509
#
# Epoch 926/999
# ----------
# train Loss: 0.1917, ROC: 0.9402, PRC: 0.7755
# val Loss: 0.2613, ROC: 0.9282, PRC: 0.7470
#
# Epoch 927/999
# ----------
# train Loss: 0.1932, ROC: 0.9390, PRC: 0.7730
# val Loss: 0.2540, ROC: 0.9301, PRC: 0.7539
#
# Epoch 928/999
# ----------
# train Loss: 0.1931, ROC: 0.9391, PRC: 0.7745
# val Loss: 0.2537, ROC: 0.9315, PRC: 0.7574
#
# Epoch 929/999
# ----------
# train Loss: 0.1916, ROC: 0.9403, PRC: 0.7757
# val Loss: 0.2524, ROC: 0.9316, PRC: 0.7577
#
# Epoch 930/999
# ----------
# train Loss: 0.1922, ROC: 0.9397, PRC: 0.7753
# val Loss: 0.2575, ROC: 0.9312, PRC: 0.7565
#
# Epoch 931/999
# ----------
# train Loss: 0.1909, ROC: 0.9410, PRC: 0.7774
# val Loss: 0.2595, ROC: 0.9309, PRC: 0.7563
#
# Epoch 932/999
# ----------
# train Loss: 0.1918, ROC: 0.9403, PRC: 0.7759
# val Loss: 0.2556, ROC: 0.9312, PRC: 0.7578
#
# Epoch 933/999
# ----------
# train Loss: 0.1888, ROC: 0.9421, PRC: 0.7829
# val Loss: 0.2502, ROC: 0.9308, PRC: 0.7560
#
# Epoch 934/999
# ----------
# train Loss: 0.1912, ROC: 0.9404, PRC: 0.7771
# val Loss: 0.2550, ROC: 0.9301, PRC: 0.7534
#
# Epoch 935/999
# ----------
# train Loss: 0.1934, ROC: 0.9388, PRC: 0.7730
# val Loss: 0.2537, ROC: 0.9309, PRC: 0.7556
#
# Epoch 936/999
# ----------
# train Loss: 0.1911, ROC: 0.9405, PRC: 0.7789
# val Loss: 0.2497, ROC: 0.9304, PRC: 0.7534
#
# Epoch 937/999
# ----------
# train Loss: 0.1919, ROC: 0.9400, PRC: 0.7761
# val Loss: 0.2503, ROC: 0.9302, PRC: 0.7536
#
# Epoch 938/999
# ----------
# train Loss: 0.1906, ROC: 0.9409, PRC: 0.7785
# val Loss: 0.2493, ROC: 0.9293, PRC: 0.7523
#
# Epoch 939/999
# ----------
# train Loss: 0.1909, ROC: 0.9409, PRC: 0.7786
# val Loss: 0.2563, ROC: 0.9300, PRC: 0.7537
#
# Epoch 940/999
# ----------
# train Loss: 0.1916, ROC: 0.9404, PRC: 0.7762
# val Loss: 0.2602, ROC: 0.9298, PRC: 0.7540
#
# Epoch 941/999
# ----------
# train Loss: 0.1943, ROC: 0.9385, PRC: 0.7700
# val Loss: 0.2553, ROC: 0.9299, PRC: 0.7543
#
# Epoch 942/999
# ----------
# train Loss: 0.1908, ROC: 0.9413, PRC: 0.7774
# val Loss: 0.2587, ROC: 0.9291, PRC: 0.7529
#
# Epoch 943/999
# ----------
# train Loss: 0.1925, ROC: 0.9397, PRC: 0.7732
# val Loss: 0.2585, ROC: 0.9303, PRC: 0.7554
#
# Epoch 944/999
# ----------
# train Loss: 0.1904, ROC: 0.9407, PRC: 0.7800
# val Loss: 0.2557, ROC: 0.9298, PRC: 0.7535
#
# Epoch 945/999
# ----------
# train Loss: 0.1931, ROC: 0.9395, PRC: 0.7728
# val Loss: 0.2516, ROC: 0.9305, PRC: 0.7554
#
# Epoch 946/999
# ----------
# train Loss: 0.1920, ROC: 0.9397, PRC: 0.7750
# val Loss: 0.2526, ROC: 0.9310, PRC: 0.7561
#
# Epoch 947/999
# ----------
# train Loss: 0.1899, ROC: 0.9413, PRC: 0.7789
# val Loss: 0.2568, ROC: 0.9316, PRC: 0.7579
#
# Epoch 948/999
# ----------
# train Loss: 0.1923, ROC: 0.9398, PRC: 0.7753
# val Loss: 0.2628, ROC: 0.9313, PRC: 0.7571
#
# Epoch 949/999
# ----------
# train Loss: 0.1921, ROC: 0.9396, PRC: 0.7755
# val Loss: 0.2599, ROC: 0.9315, PRC: 0.7546
#
# Epoch 950/999
# ----------
# train Loss: 0.1933, ROC: 0.9396, PRC: 0.7720
# val Loss: 0.2518, ROC: 0.9314, PRC: 0.7574
#
# Epoch 951/999
# ----------
# train Loss: 0.1920, ROC: 0.9400, PRC: 0.7757
# val Loss: 0.2556, ROC: 0.9308, PRC: 0.7555
#
# Epoch 952/999
# ----------
# train Loss: 0.1935, ROC: 0.9395, PRC: 0.7733
# val Loss: 0.2568, ROC: 0.9309, PRC: 0.7564
#
# Epoch 953/999
# ----------
# train Loss: 0.1932, ROC: 0.9393, PRC: 0.7746
# val Loss: 0.2658, ROC: 0.9309, PRC: 0.7548
#
# Epoch 954/999
# ----------
# train Loss: 0.1919, ROC: 0.9395, PRC: 0.7760
# val Loss: 0.2574, ROC: 0.9298, PRC: 0.7517
#
# Epoch 955/999
# ----------
# train Loss: 0.1905, ROC: 0.9407, PRC: 0.7805
# val Loss: 0.2594, ROC: 0.9300, PRC: 0.7506
#
# Epoch 956/999
# ----------
# train Loss: 0.1927, ROC: 0.9392, PRC: 0.7748
# val Loss: 0.2557, ROC: 0.9304, PRC: 0.7539
#
# Epoch 957/999
# ----------
# train Loss: 0.1900, ROC: 0.9411, PRC: 0.7793
# val Loss: 0.2557, ROC: 0.9310, PRC: 0.7563
#
# Epoch 958/999
# ----------
# train Loss: 0.1906, ROC: 0.9409, PRC: 0.7789
# val Loss: 0.2583, ROC: 0.9307, PRC: 0.7556
#
# Epoch 959/999
# ----------
# train Loss: 0.1916, ROC: 0.9403, PRC: 0.7757
# val Loss: 0.2594, ROC: 0.9306, PRC: 0.7544
#
# Epoch 960/999
# ----------
# train Loss: 0.1909, ROC: 0.9415, PRC: 0.7767
# val Loss: 0.2604, ROC: 0.9306, PRC: 0.7493
#
# Epoch 961/999
# ----------
# train Loss: 0.1910, ROC: 0.9408, PRC: 0.7786
# val Loss: 0.2565, ROC: 0.9305, PRC: 0.7523
#
# Epoch 962/999
# ----------
# train Loss: 0.1902, ROC: 0.9410, PRC: 0.7798
# val Loss: 0.2580, ROC: 0.9308, PRC: 0.7546
#
# Epoch 963/999
# ----------
# train Loss: 0.1912, ROC: 0.9406, PRC: 0.7750
# val Loss: 0.2696, ROC: 0.9300, PRC: 0.7478
#
# Epoch 964/999
# ----------
# train Loss: 0.1911, ROC: 0.9406, PRC: 0.7772
# val Loss: 0.2610, ROC: 0.9304, PRC: 0.7514
#
# Epoch 965/999
# ----------
# train Loss: 0.1916, ROC: 0.9407, PRC: 0.7760
# val Loss: 0.2658, ROC: 0.9304, PRC: 0.7496
#
# Epoch 966/999
# ----------
# train Loss: 0.1929, ROC: 0.9402, PRC: 0.7708
# val Loss: 0.2602, ROC: 0.9308, PRC: 0.7505
#
# Epoch 967/999
# ----------
# train Loss: 0.1916, ROC: 0.9399, PRC: 0.7754
# val Loss: 0.2645, ROC: 0.9304, PRC: 0.7493
#
# Epoch 968/999
# ----------
# train Loss: 0.1904, ROC: 0.9413, PRC: 0.7788
# val Loss: 0.2550, ROC: 0.9313, PRC: 0.7530
#
# Epoch 969/999
# ----------
# train Loss: 0.1893, ROC: 0.9422, PRC: 0.7797
# val Loss: 0.2545, ROC: 0.9310, PRC: 0.7555
#
# Epoch 970/999
# ----------
# train Loss: 0.1929, ROC: 0.9394, PRC: 0.7737
# val Loss: 0.2533, ROC: 0.9306, PRC: 0.7545
#
# Epoch 971/999
# ----------
# train Loss: 0.1907, ROC: 0.9414, PRC: 0.7768
# val Loss: 0.2569, ROC: 0.9311, PRC: 0.7563
#
# Epoch 972/999
# ----------
# train Loss: 0.1889, ROC: 0.9420, PRC: 0.7805
# val Loss: 0.2594, ROC: 0.9308, PRC: 0.7557
#
# Epoch 973/999
# ----------
# train Loss: 0.1894, ROC: 0.9422, PRC: 0.7803
# val Loss: 0.2562, ROC: 0.9304, PRC: 0.7539
#
# Epoch 974/999
# ----------
# train Loss: 0.1897, ROC: 0.9415, PRC: 0.7799
# val Loss: 0.2567, ROC: 0.9296, PRC: 0.7508
#
# Epoch 975/999
# ----------
# train Loss: 0.1913, ROC: 0.9404, PRC: 0.7774
# val Loss: 0.2594, ROC: 0.9288, PRC: 0.7488
#
# Epoch 976/999
# ----------
# train Loss: 0.1909, ROC: 0.9407, PRC: 0.7781
# val Loss: 0.2666, ROC: 0.9281, PRC: 0.7465
#
# Epoch 977/999
# ----------
# train Loss: 0.1935, ROC: 0.9388, PRC: 0.7733
# val Loss: 0.2668, ROC: 0.9278, PRC: 0.7465
#
# Epoch 978/999
# ----------
# train Loss: 0.1916, ROC: 0.9405, PRC: 0.7765
# val Loss: 0.2701, ROC: 0.9283, PRC: 0.7432
#
# Epoch 979/999
# ----------
# train Loss: 0.1943, ROC: 0.9385, PRC: 0.7715
# val Loss: 0.2693, ROC: 0.9281, PRC: 0.7474
#
# Epoch 980/999
# ----------
# train Loss: 0.1915, ROC: 0.9403, PRC: 0.7768
# val Loss: 0.2620, ROC: 0.9292, PRC: 0.7502
#
# Epoch 981/999
# ----------
# train Loss: 0.1937, ROC: 0.9389, PRC: 0.7717
# val Loss: 0.2653, ROC: 0.9296, PRC: 0.7505
#
# Epoch 982/999
# ----------
# train Loss: 0.1894, ROC: 0.9417, PRC: 0.7811
# val Loss: 0.2620, ROC: 0.9295, PRC: 0.7505
#
# Epoch 983/999
# ----------
# train Loss: 0.1899, ROC: 0.9417, PRC: 0.7799
# val Loss: 0.2620, ROC: 0.9299, PRC: 0.7511
#
# Epoch 984/999
# ----------
# train Loss: 0.1906, ROC: 0.9409, PRC: 0.7788
# val Loss: 0.2599, ROC: 0.9302, PRC: 0.7495
#
# Epoch 985/999
# ----------
# train Loss: 0.1911, ROC: 0.9406, PRC: 0.7768
# val Loss: 0.2679, ROC: 0.9300, PRC: 0.7484
#
# Epoch 986/999
# ----------
# train Loss: 0.1913, ROC: 0.9403, PRC: 0.7774
# val Loss: 0.2564, ROC: 0.9308, PRC: 0.7563
#
# Epoch 987/999
# ----------
# train Loss: 0.1926, ROC: 0.9397, PRC: 0.7726
# val Loss: 0.2577, ROC: 0.9299, PRC: 0.7484
#
# Epoch 988/999
# ----------
# train Loss: 0.1915, ROC: 0.9403, PRC: 0.7754
# val Loss: 0.2620, ROC: 0.9282, PRC: 0.7460
#
# Epoch 989/999
# ----------
# train Loss: 0.1903, ROC: 0.9412, PRC: 0.7785
# val Loss: 0.2578, ROC: 0.9308, PRC: 0.7561
#
# Epoch 990/999
# ----------
# train Loss: 0.1922, ROC: 0.9404, PRC: 0.7743
# val Loss: 0.2656, ROC: 0.9297, PRC: 0.7518
#
# Epoch 991/999
# ----------
# train Loss: 0.1908, ROC: 0.9409, PRC: 0.7761
# val Loss: 0.2603, ROC: 0.9305, PRC: 0.7546
#
# Epoch 992/999
# ----------
# train Loss: 0.1908, ROC: 0.9410, PRC: 0.7777
# val Loss: 0.2591, ROC: 0.9300, PRC: 0.7534
#
# Epoch 993/999
# ----------
# train Loss: 0.1910, ROC: 0.9407, PRC: 0.7784
# val Loss: 0.2604, ROC: 0.9295, PRC: 0.7512
#
# Epoch 994/999
# ----------
# train Loss: 0.1913, ROC: 0.9398, PRC: 0.7788
# val Loss: 0.2612, ROC: 0.9294, PRC: 0.7510
#
# Epoch 995/999
# ----------
# train Loss: 0.1914, ROC: 0.9408, PRC: 0.7750
# val Loss: 0.2745, ROC: 0.9267, PRC: 0.7436
#
# Epoch 996/999
# ----------
# train Loss: 0.1908, ROC: 0.9407, PRC: 0.7785
# val Loss: 0.2550, ROC: 0.9297, PRC: 0.7520
#
# Epoch 997/999
# ----------
# train Loss: 0.1918, ROC: 0.9402, PRC: 0.7776
# val Loss: 0.2539, ROC: 0.9304, PRC: 0.7546
#
# Epoch 998/999
# ----------
# train Loss: 0.1915, ROC: 0.9407, PRC: 0.7735
# val Loss: 0.2592, ROC: 0.9303, PRC: 0.7551
#
# Epoch 999/999
# ----------
# train Loss: 0.1901, ROC: 0.9409, PRC: 0.7811
# val Loss: 0.2672, ROC: 0.9296, PRC: 0.7531
#
# Training complete in 9m 39s
# Best val ROC: 0.932652
# Best val PRC: 0.759197
# Best val Loss: 0.231144
#
#  - - - - - TIME: 9.649324361483256 mins - - - - -
#
#  - - - - - BEST VAL:  0.932652057071637 - - - - -
# accuracy: 0.77068345323741 857 1112

# %%
def eval_model(model, thresh=0.5):
    
    model.eval()
        
    BATCH_SIZE = len(motifs_test)

    train = data_utils.TensorDataset(features_test, target_test)
    train_loader = data_utils.DataLoader(train, batch_size=BATCH_SIZE, shuffle=True, drop_last=False)
    
    for inputs, labels in train_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)
        
        sentence = inputs[:,:,:len(amino_acids)]
        coords = inputs[:,:,len(amino_acids):]
        outputs = model(sentence=sentence,coords=coords)   # Set model to evaluate mode

        accuracy = 0
        totTrues = 0
        for i,out in enumerate(outputs):
            pred = numpy.where(out.cpu().detach().numpy() > thresh)[0]
            if len(pred)<1: 
                pred = [numpy.argmax(out.cpu().detach().numpy())]
            true = numpy.where(labels.data.cpu()[i]==1)[0]
            totTrues += len(true)
            accuracy += len(pred)

        y_score = outputs.cpu().detach().numpy()
        y_test = numpy.array(labels.cpu())
        
        print("accuracy:",accuracy/totTrues,accuracy,totTrues)
        
        return (accuracy/BATCH_SIZE, y_score, y_test)

# %%
eval_model
# Out:
# <function __main__.eval_model(model, thresh=0.5)>

# %%
# motifDrpt = 0.5
# coordDrpt = 0.5
# catDrpt = 0.0

# totAcc = []
# totY_score = []
# totY_test = []

# myBestModel = Model(BS,motifDrpt,coordDrpt,catDrpt) 
# myBestModel = myBestModel1.to(device)


# myBestModel1.load_state_dict(torch.load('predModel_results/siam_08/models/01_seqCoord_666_64-32-8_3conv-2fc-3conv-2fc-1cat_123_0*50motifs-0*50coords-0*00cat_ROC_MSEphylo_512_1000_O'))
# (accuracy, y_score, y_test) = eval_model(myBestModel, thresh=0.5)

# totAcc.append(accuracy)
# totY_score.extend(y_score)
# totY_test.extend(y_test)

# %%
import os
f = "predModel_results/siam_%s/" % siamRun

allDone()
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="http://www.wavsource.com/snds_2018-06-03_5106726768923853/animals/cat_meow2.wav" type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# os.mkdir(f)
siamRun
# Out:
# '08'

# %%
f
# Out:
# 'predModel_results/siam_08/'

# %%
run = '15'

versionToUse_ = versionToUse
mySeed_ = str(mySeed)
neurons_ = '%d-%d-%d' % (HIDDEN_DIM_0, HIDDEN_DIM_1, OUT_DIM)
layers_ = '3conv-2fc-3conv-2fc-1cat'
kernels_ = '123'
drpt_ = '%1.2fmotifs-%1.2fcoords-%1.2fcat' % (motifDrpt,coordDrpt,catDrpt)
stopper_ = stopper
thisLoss_ = thisLoss
bs_ =  str(BS)
num_epochs_ = str(num_epochs) 
other_ = 'O'

attributes = [run, versionToUse_, mySeed_, neurons_, layers_, kernels_, drpt_, stopper_, 
              thisLoss_, bs_, num_epochs_, other_]
modelDescription = '_'.join(attributes)
modelDescription = modelDescription.replace('.','*')
modelDescription = modelDescription.replace('~','')
fName = f + 'models/' + modelDescription
fName
# Out:
# 'predModel_results/siam_08/models/15_seqs_666_64-32-8_3conv-2fc-3conv-2fc-1cat_123_0*50motifs-0*50coords-0*00cat_Loss_BCE_256_1000_O'

# %%
torch.save(myBestModel.state_dict(), fName)

# %%
figFile = f + 'figs/'
# os.mkdir(figFile)

figFile
# Out:
# 'predModel_results/siam_08/figs/'

# %%
avg_losses = []
for i in range(len(tLoss1[0])):
    avg_loss = sum([x[i] for x in tLoss1]) / len(tLoss1)
    avg_losses.append(avg_loss)
    
avg_val_losses = []
for i in range(len(vLoss1[0])):
    avg_loss = sum([x[i] for x in vLoss1]) / len(vLoss1)
    avg_val_losses.append(avg_loss)
    
avg_acc_history = []
for i in range(len(tAcc1[0])):
    avg_acc = sum([x[i] for x in tAcc1]) / len(tAcc1)
    avg_acc_history.append(avg_acc)
    
avg_val_acc_history = []
for i in range(len(vAcc1[0])):
    avg_acc = sum([x[i] for x in vAcc1]) / len(vAcc1)
    avg_val_acc_history.append(avg_acc)
    
import matplotlib.ticker as ticker
plt.style.use('seaborn-whitegrid')

plt.rcParams['xtick.major.pad']='12'
plt.rcParams['ytick.major.pad']='12'

# plt.figure(figsize=(18,13))
plt.figure(figsize=(9,6.5))

plt.title("Loss" ,fontsize=20, pad=10)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Iterations', fontsize=20, labelpad=10)
plt.ylabel('Score', fontsize=20, labelpad=10)
plt.plot(avg_losses, label='Training loss', linewidth=1.5)
plt.plot(avg_val_losses, label='Validation loss', linewidth=1.5)
plt.legend(loc='upper right',fontsize=15, facecolor="white",frameon=True,framealpha=1.0)
plt.tight_layout()
plt.savefig(figFile + run + "_loss")

# %%
plt.rcParams['xtick.major.pad']='12'
plt.rcParams['ytick.major.pad']='12'

plt.figure(figsize=(9,6.5))
plt.title("%s " % ("ROC"),fontsize=20, pad=10)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Iterations', fontsize=20, labelpad=10)
plt.ylabel('Score', fontsize=20, labelpad=10)
plt.plot(avg_acc_history, label='Training ROC', linewidth=1.5)
plt.plot(avg_val_acc_history, label='Validation ROC', linewidth=1.5)
plt.legend(loc='lower right',fontsize=15, facecolor="white",frameon=True,framealpha=1.0)
plt.tight_layout()
plt.savefig(figFile + run + "_stopper")

# %%
y_test = numpy.array(totY_test)
y_score = numpy.array(totY_score)

for i in range(len(y_test)):
    trueIdc = numpy.where(y_test[i]==1)[0]
    predIdc = numpy.where(y_score[i]>0.5)[0]
    if len(predIdc)<1:
        predIdc = [numpy.argmax(y_score[i])]
        
    trueLab = fams[trueIdc]
    predLab = fams[predIdc]
y_test.shape
# Out:
# (857, 8)

# %%
from itertools import chain
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score

# For each class
precision = dict()
recall = dict()
average_precision = dict()

for i in range(len(fams)):
    precision[i], recall[i], _ = precision_recall_curve(y_test[:, i],
                                                        y_score[:, i])
    average_precision[i] = average_precision_score(y_test[:, i], y_score[:, i])

# A "micro-average": quantifying score on all classes jointly
precision["micro"], recall["micro"], _ = precision_recall_curve(y_test.ravel(),
    y_score.ravel())
average_precision["micro"] = average_precision_score(y_test, y_score,
                                                     average="micro")
print('Average precision score, micro-averaged over all classes: {0:0.3f}'
      .format(average_precision["micro"]))



average_precision["micro"] = average_precision_score(y_test, y_score,
                                                     average="micro")
average_precision["macro"] = average_precision_score(y_test, y_score,
                                                     average="macro")

print('Average precision score, micro-averaged over all classes: {0:0.3f}'
      .format(average_precision["macro"]))
# Out:
# Average precision score, micro-averaged over all classes: 0.698
# Average precision score, micro-averaged over all classes: 0.694

# %%
from sklearn.metrics import roc_curve, auc
from scipy import interp
import numpy as np

FAM_IDC = [x for x in range(len(fams))]

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in FAM_IDC:
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])


# Compute macro-average ROC curve and ROC area
# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in FAM_IDC]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in FAM_IDC:
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= len(FAM_IDC)

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# %%
from itertools import cycle
# colors = cycle(['blue', 'yellowgreen', 'darkorange', 'magenta', 'green','gold','red','turquoise','brown','tomato',
#                'purple','pink','orchid']) 
# colors = cycle(['brown','red','tomato','orange','gold','#E3CF57','yellowgreen','green','turquoise','blue','navy','purple','orchid','pink',
#                 'magenta']) 
# colors = cycle(['red','orange','#E3CF57','green','blue', 'purple']) 


colors = cycle(['red','magenta','orange', 'gold','yellowgreen',
                'turquoise', 'blue', 'purple']) 

plt.style.use('default')
fig, (ax1, ax2) = plt.subplots(2,figsize=(5,11))
lw = 1.25

ax1.plot(fpr["micro"], tpr["micro"],label='micro-average (area = {0:0.3f})'''.format(roc_auc["micro"]), 
         color='white', linestyle=':', linewidth=lw)
ax1.plot(fpr["macro"], tpr["macro"], label='macro-average (area = {0:0.3f})'''.format(roc_auc["macro"]),
         color='white', linestyle=':', linewidth=lw)

for i, color in zip( range( len(fams) ), colors):
    fam = fams[i]
#     print(color)
    ax1.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='{0} (area = {1:0.3f})'
             ''.format(fam, roc_auc[i]))

fig.subplots_adjust(hspace=.275)
ax1.plot([0, 1], [0, 1], 'k--', lw=lw)
ax1.set_xlim([0.0, 1.0])
ax1.set_ylim([0.0, 1.05])
ax1.tick_params(axis="x", labelsize=10)
ax1.tick_params(axis="y", labelsize=10)
ax1.set_xlabel('False Positive Rate',fontsize=12) #20)
ax1.set_ylabel('True Positive Rate',fontsize=12) #20)
ax1.set_title('ROC curve per kinase family',fontsize=12) #=20)
ax1.legend(loc=(1.05, .0), fontsize=7.5) #12.5)

# colors = cycle(['magenta','red','orange', 'gold', '#E3CF57','yellowgreen','green','turquoise','blue','purple','orchid','pink',
#                 'magenta']) 

colors = cycle(['red','magenta','orange', 'gold','yellowgreen',
                'turquoise', 'blue', 'purple']) 

lines = []
labels = []


l, = ax2.plot(recall["micro"], precision["micro"], color='white', lw=1.5,linestyle=':')
lines.append(l)
labels.append('micro-average (area = {0:0.3f})'
              ''.format(average_precision["micro"]))
l, = ax2.plot(recall["micro"], precision["micro"], color='white', lw=1.5,linestyle=':')
lines.append(l)
labels.append('macro-average (area = {0:0.3f})'
              ''.format(average_precision["macro"]))

for i, color in zip(range( len(fams) ), colors):
    l, = plt.plot(recall[i], precision[i], color=color, lw=lw)
#     print(color)
    lines.append(l)
    fclass = fams[i]
    labels.append('{0} (area = {1:0.3f})'
                  ''.format(fclass, average_precision[i]))

ax2.set_xlim([0.0, 1.0])
ax2.set_ylim([0.0, 1.05])
ax2.tick_params(axis="x", labelsize=10)
ax2.tick_params(axis="y", labelsize=10)
ax2.set_xlabel('Recall',fontsize=12) #20)
ax2.set_ylabel('Precision',fontsize=12) #20)
ax2.set_title('Precision-recall curve per kinase family',fontsize=12) #=20)
ax2.legend(lines, labels, loc=(1.05, .0), fontsize=7.5) #12.5)

plt.savefig(figFile + run + "_roc_prc", bbox_inches='tight')
plt.show()

# %%
def eval_model2(model, thresh=0.5):
        
    BATCH_SIZE = len(motifs_test)

    train = data_utils.TensorDataset(features_test, target_test)
    train_loader = data_utils.DataLoader(train, batch_size=BATCH_SIZE, shuffle=True, drop_last=False)
    
    for inputs, labels in train_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        model.eval()   # Set model to evaluate mode
        
        
        sentence = inputs[:,:,:len(amino_acids)]
        coords = inputs[:,:,len(amino_acids):]
        outputs = model.forward(sentence=sentence, coords=coords)

        confusion = torch.zeros(len(fams), len(fams))
        accuracy = 0.0
        for i,out in enumerate(outputs):
            pred = numpy.where(out.cpu().detach().numpy() > thresh)[0]
            if len(pred)<1:
                pred = [numpy.argmax(out.cpu().detach().numpy())]
            true = numpy.where(labels.data.cpu()[i]==1)[0]
            for pIdx in pred:
                for tIdx in true:
                    confusion[pIdx][tIdx] += 1
            if any(true) in pred:
                accuracy+=1

        y_score = outputs.cpu().detach().numpy()
        y_test = numpy.array(labels.cpu())
        
        print(accuracy)
        
        return (confusion, accuracy/BATCH_SIZE, y_score, y_test)

# %%
import math

confusion = torch.zeros(len(fams), len(fams))
(confusion, accuracy, y_score, y_test) = eval_model2(myBestModel, thresh=0.5)

labs = confusion.detach().numpy().copy()

for i in range(len(fams)):
    confusion[i] = confusion[i] / confusion[i].sum()
# print (confusion)
for i in range(len(fams)):
    for j in range(len(fams)):
        if math.isnan(confusion[i][j]) or confusion[i][j]==0:
            confusion[i][j]=0
            
import seaborn as sb
heat_map = sb.heatmap(confusion, annot=labs, cmap="GnBu_r", fmt='1.0f',
                      square=False, yticklabels=fams, xticklabels=fams )

b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values

plt.xlabel("True label",fontsize=12, labelpad=10)
plt.ylabel("Predicted label",fontsize=12, labelpad=10)
plt.title("Confusion matrix for kinase labels",fontsize=12, pad=12)
plt.savefig(figFile + run + "_conf") #, bbox_inches='tight')
plt.show()
# Out:
# 43.0
